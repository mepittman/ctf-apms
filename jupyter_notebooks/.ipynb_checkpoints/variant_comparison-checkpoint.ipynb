# %%
library(RCurl)
library(XML)
library(biomaRt)
library(data.table)
# Out:
# Loading required package: bitops
# Registered S3 method overwritten by 'openssl':
#   method      from
#   print.bytes Rcpp

# %%
DNV_cases = read.csv('../data/variants/DNV_cases.csv', stringsAsFactors = FALSE)
DNV_ctrls = read.csv('../data/variants/DNV_ctrls.csv', stringsAsFactors = FALSE)
DNV_cases$variant_type = ifelse(DNV_cases$Variant.Class == "syn", "Case Synonymous", "Case Non-synonymous")
DNV_ctrls$variant_type = ifelse(DNV_ctrls$Variant.Class == "syn", "Control Synonymous", "Control Non-synonymous")

names(DNV_cases)[which(names(DNV_cases) == "CHR")] <- "CHROM"
cols  = c("Blinded.ID","CHROM","POS",'REF','ALT','Variant.Class','variant_type','Gene', 'HHE.Rank')
combined = rbind(DNV_cases[,cols], DNV_ctrls[,cols])
head(combined)
# Out:
#   Blinded.ID CHROM POS       REF ALT Variant.Class variant_type        Gene
# 1 GT04011952 19      8491545 C   G   mis           Case Non-synonymous MARCH2
# 2 1-00788    10     94070938 G   A   mis           Case Non-synonymous MARCH5
# 3 1-01469    2     242275458 C   T   mis           Case Non-synonymous SEPT2
# 4 1-06549    22     42382110 G   A   mis           Case Non-synonymous SEPT3
# 5 1-05720    17     56604065 A   C   mis           Case Non-synonymous SEPT4
# 6 1-07417    5     132097207 C   G   misD          Case Non-synonymous SEPT8
#   HHE.Rank
# 1 70.2
# 2 75.1
# 3 98.1
# 4 50.4
# 5 54.4
# 6 86.4

# %%
combined$ID = "."
cadd_input = combined[,c('CHROM','POS','ID','REF','ALT')]
write.table(cadd_input, file = '../intermediate/cadd_upload.vcf', 
            sep = "\t", row.names=FALSE, quote=FALSE)

# %%
gt_df = read.table('../intermediate/interactome_lists/GATA4-TBX5_genes.txt', stringsAsFactors=FALSE)
gt_interactome = gt_df$V1

genes = strsplit(gt_interactome, ';')
gene_list = unlist(genes, recursive=FALSE)

combined$Interactome = ifelse(combined$Gene %in% gt_interactome, "Interactome", "Non-interactome")
combined$variant_type_2 = paste0(combined$variant_type, '_', combined$Interactome)
head(combined)
# Out:
#   Blinded.ID CHROM POS       REF ALT Variant.Class variant_type        Gene
# 1 GT04011952 19      8491545 C   G   mis           Case Non-synonymous MARCH2
# 2 1-00788    10     94070938 G   A   mis           Case Non-synonymous MARCH5
# 3 1-01469    2     242275458 C   T   mis           Case Non-synonymous SEPT2
# 4 1-06549    22     42382110 G   A   mis           Case Non-synonymous SEPT3
# 5 1-05720    17     56604065 A   C   mis           Case Non-synonymous SEPT4
# 6 1-07417    5     132097207 C   G   misD          Case Non-synonymous SEPT8
#   HHE.Rank ID Interactome     variant_type_2
# 1 70.2     .  Non-interactome Case Non-synonymous_Non-interactome
# 2 75.1     .  Non-interactome Case Non-synonymous_Non-interactome
# 3 98.1     .  Non-interactome Case Non-synonymous_Non-interactome
# 4 50.4     .  Non-interactome Case Non-synonymous_Non-interactome
# 5 54.4     .  Non-interactome Case Non-synonymous_Non-interactome
# 6 86.4     .  Non-interactome Case Non-synonymous_Non-interactome

# %%
unique(combined$variant_type)
# Out:
# [1] "Case Non-synonymous"    "Case Synonymous"        "Control Non-synonymous"
# [4] "Control Synonymous"

# %% [markdown]
# ## CADD score

# %%
cadd_df = read.table('../data/cadd/cadd_scores.tsv', stringsAsFactors = FALSE, sep="\t", 
                     col.names = c('CHROM','POS','REF','ALT','CADD.score','PHRED.score'))

df = merge(combined, cadd_df, all.x = TRUE)

# %% [markdown]
# ## gnomAD pLI and observed/expected score

# %%
gnomad = read.table('../data/databases/gnomad_constraint.txt', sep = "\t", stringsAsFactors=FALSE, header=TRUE)
df$Gene[which(!df$Gene %in% gnomad$gene)]
# Out:
# [1] "9-Sep" "HSH2D"

# %%
df$Gene[which(df$Gene == "9-Sep")] <- 'SEPT9'
df = merge(df, gnomad[,c('gene','oe_mis','oe_lof','oe_syn','pLI')], by.x='Gene', by.y='gene', all.x = TRUE)

# %%
# Create column with relevant oe score (oe_mis for missense variants, oe_lof for loss-of-function variants)
df$oe = NA

for(i in c(1:nrow(df))){
    if (df$Variant.Class[i] %in% c("mis","misD")){
        df$oe[i] = df$oe_mis[i]
    } else if(df$Variant.Class[i] %in% c("non","frameshift","startloss","splice","stoploss")){
        df$oe[i] = df$oe_lof[i]
    } else if(df$Variant.Class[i] == 'syn'){
        df$oe[i] = df$oe_syn[i]
    }
}

# %% [markdown]
# ## Node degree: other DNV genes

# %%
iref = read.table('../data/databases/mammalian_iRefIndex.txt', sep='\t', stringsAsFactors=F, header=T)

# %%
nonsyn_dnvs = unique(DNV_cases[which(DNV_cases$Variant.Class != "syn"), 'Gene'])

# %%
#Create data table to save overall connectivity of each interactome gene
gene_conn = data.frame(Gene = unique(df$Gene))
gene_conn$total_connections = 0

for (g in gene_conn$Gene){
  lines = iref[which(iref$aliasA == g | iref$aliasB == g),]
  
  # Remove self-loops
  lines = lines[which(lines$aliasA != lines$aliasB),c('aliasA','aliasB')]
  
  # Remove transitive interactions
  swap_lines = lines[,c('aliasB','aliasA')]
  names(swap_lines) = c('aliasA','aliasB')
  both = rbind(lines, swap_lines)
  both = unique(both)
  degree = nrow(both)/2
  
  gene_conn$total_connections[which(gene_conn$Gene == g)] = degree
  
}

# Connectivity to other DNV genes
first_interactome = iref[which(iref$aliasA %in% nonsyn_dnvs | iref$aliasB %in% nonsyn_dnvs),]
df$dnv_node_degree = 0
df$corrected_dnv_node_degree = 0

for(i in c(1:nrow(df))){
  lines = unique(first_interactome[which(first_interactome$aliasA == df$Gene[i] | 
                                           first_interactome$aliasB == df$Gene[i]), c('aliasA','aliasB')])
  
  # Remove self-loops
  lines = lines[which(lines$aliasA != lines$aliasB),]
  
  # Remove transitive interactions
  swap_lines = lines[,c('aliasB','aliasA')]
  names(swap_lines) = c('aliasA','aliasB')
  both = rbind(lines, swap_lines)
  both = unique(both)
  degree = nrow(both)/2
  df$dnv_node_degree[i] = degree
  df$corrected_dnv_node_degree[i] = degree/gene_conn$total_connections[which(gene_conn$Gene == df$Gene[i])]
}

# %% [markdown]
# ## Node degree - known CHD genes

# %%
known = read.table('../data/databases/known_CHD_genes.txt', stringsAsFactors = FALSE)
known_genes = known$V1

# %%
# Connectivity to known CHD genes
first_interactome = iref[which(iref$aliasA %in% known_genes | iref$aliasB %in% known_genes),]
df$chd_node_degree = 0
df$corrected_chd_node_degree = 0

for(i in c(1:nrow(df))){
  lines = unique(first_interactome[which(first_interactome$aliasA == df$Gene[i] | 
                                           first_interactome$aliasB == df$Gene[i]), c('aliasA','aliasB')])
  
  # Remove self-loops
  lines = lines[which(lines$aliasA != lines$aliasB),]
  
  # Remove transitive interactions
  swap_lines = lines[,c('aliasB','aliasA')]
  names(swap_lines) = c('aliasA','aliasB')
  both = rbind(lines, swap_lines)
  both = unique(both)
  degree = nrow(both)/2
  df$chd_node_degree[i] = degree
  df$corrected_chd_node_degree[i] = degree/gene_conn$total_connections[which(gene_conn$Gene == df$Gene[i])]
}

# %%
df
# Out:
#      Gene    CHROM POS       REF   ALT Blinded.ID Variant.Class
# 1    A2M     12      9265970 A     G   14397      mis
# 2    AAAS    12     53701325 G     C   1-02674    mis
# 3    AACS    12    125621409 C     T   GT04016012 mis
# 4    AAK1    2      69748004 C     T   1-06459    mis
# 5    AAMP    2     219130141 T     A   11984      mis
# 6    AASS    7     121769559 C     T   1-00100    syn
# 7    ABAT    16      8870306 C     T   1-04638    mis
# 8    ABCA12  2     215818801 G     T   11405      mis
# 9    ABCA12  2     215917234 C     T   12994      mis
# 10   ABCA13  7      48315282 C     A   11513      mis
# 11   ABCA13  7      48287896 G     C   1-01866    mis
# 12   ABCA13  7      48313603 C     G   1-05977    mis
# 13   ABCA13  7      48237892 T     G   1-07342    syn
# 14   ABCA3   16      2358475 G     A   14095      mis
# 15   ABCA4   1      94495150 G     C   13093      misD
# 16   ABCA4   1      94574138 A     G   1-02035    mis
# 17   ABCA7   19      1056184 G     A   1-03865    mis
# 18   ABCA8   17     66924150 C     T   1-00416    mis
# 19   ABCA8   17     66925280 C     A   1-05296    syn
# 20   ABCB11  2     169780296 G     A   11251      misD
# 21   ABCB6   2     220082869 G     C   1-01951    mis
# 22   ABCC1   16     16230394 G     A   11008      syn
# 23   ABCC11  16     48261823 C     T   14316      mis
# 24   ABCC2   10    101578577 C     T   1-12717    misD
# 25   ABCC3   17     48762187 C     T   1-06692    non
# 26   ABCC6   16     16272712 G     A   13621      syn
# 27   ABCC8   11     17448603 A     G   13692      misD
# 28   ABCD3   1      94943860 A     G   1-06555    misD
# 29   ABCE1   4     146025629 G     A   1-07919    misD
# 30   ABCG1   21     43710254 T     C   1-04276    misD
# ...  ...     ...   ...       ...   ... ...        ...
# 4796 ZNF764  16     30567251 G     C   1-13246    mis
# 4797 ZNF766  19     52793553 A     AT  1-01678    frameshift
# 4798 ZNF77   19      2933528 C     A   SSC06838   mis
# 4799 ZNF780A 19     40580566 G     C   12285      mis
# 4800 ZNF780A 19     40580705 T     C   14018      syn
# 4801 ZNF780A 19     40581783 C     T   14008      mis
# 4802 ZNF780B 19     40553282 C     T   11622      mis
# 4803 ZNF782  9      99581083 G     A   1-06370    mis
# 4804 ZNF786  7     148769528 G     C   13859      mis
# 4805 ZNF79   9     130207133 G     T   1-02338    mis
# 4806 ZNF814  19     58385008 A     T   1-04949    mis
# 4807 ZNF829  19     37383058 T     C   1-06236    mis
# 4808 ZNF830  17     33289423 G     A   11775      mis
# 4809 ZNF835  19     57176092 T     C   14339      mis
# 4810 ZNF853  7       6656905 G     C   1-07175    mis
# 4811 ZNF878  19     12155806 T     C   1-01132    mis
# 4812 ZNFX1   20     47864195 T     C   1-02254    mis
# 4813 ZNFX1   20     47887228 C     T   1-03696    misD
# 4814 ZP1     11     60637182 TCCTC T   14018      frameshift
# 4815 ZP4     1     238053472 G     A   1-09567    syn
# 4816 ZSCAN12 6      28365980 C     T   1-02814    mis
# 4817 ZSCAN2  15     85164635 A     G   1-01076    syn
# 4818 ZSCAN20 1      33954136 G     T   1-00877    mis
# 4819 ZSWIM4  19     13915878 G     A   14563      mis
# 4820 ZSWIM6  5      60826000 C     A   1-03260    mis
# 4821 ZSWIM6  5      60768572 C     T   SSC07834   syn
# 4822 ZSWIM8  10     75551724 G     A   1-04504    mis
# 4823 ZW10    11    113614530 T     C   GT04012081 mis
# 4824 ZW10    11    113631634 G     A   11474      mis
# 4825 ZYG11A  1      53323026 C     T   11472      mis
#      variant_type           HHE.Rank ID  ... PHRED.score oe_mis  oe_lof
# 1    Control Non-synonymous 33.3     .   ... 24.300      0.81065 0.405260
# 2    Case Non-synonymous    80.1     .   ... 22.400      1.05910 0.707340
# 3    Case Non-synonymous    45.8     .   ... 33.000      0.97211 0.798010
# 4    Case Non-synonymous    83.5     .   ... 31.000      0.67376 0.041108
# 5    Control Non-synonymous 93.6     .   ... 24.200      0.69331 0.179410
# 6    Case Synonymous        23.9     .   ... 11.330      0.88950 0.583280
# 7    Case Non-synonymous    86.6     .   ... 22.600      0.90591 0.324760
# 8    Control Non-synonymous 24.2     .   ... 20.800      0.87450 0.377260
# 9    Control Non-synonymous 24.2     .   ... 13.460      0.87450 0.377260
# 10   Control Non-synonymous 14.2     .   ...  0.040      1.08650 0.915340
# 11   Case Non-synonymous    14.2     .   ... 16.210      1.08650 0.915340
# 12   Case Non-synonymous    14.2     .   ... 12.390      1.08650 0.915340
# 13   Case Synonymous        14.2     .   ... 10.520      1.08650 0.915340
# 14   Control Non-synonymous 76.4     .   ... 13.650      0.97157 0.361140
# 15   Control Non-synonymous 41.3     .   ... 23.200      1.05260 0.763330
# 16   Case Non-synonymous    41.3     .   ... 15.450      1.05260 0.763330
# 17   Case Non-synonymous    54.2     .   ... 10.620      1.11210 0.895260
# 18   Case Non-synonymous    34.9     .   ...  0.169      1.01860 0.984500
# 19   Case Synonymous        34.9     .   ...  0.654      1.01860 0.984500
# 20   Control Non-synonymous 9.5      .   ... 32.000      0.88341 0.472910
# 21   Case Non-synonymous    N/A      .   ... 19.080      1.01750 0.737140
# 22   Control Synonymous     37.1     .   ...  1.954      0.83676 0.275930
# 23   Control Non-synonymous N/A      .   ...  0.003      1.01970 1.011600
# 24   Case Non-synonymous    16.1     .   ... 31.000      1.09990 0.953040
# 25   Case Non-synonymous    32.8     .   ... 43.000      0.94097 0.711490
# 26   Control Synonymous     10.3     .   ...  0.154      1.10580 0.827670
# 27   Control Non-synonymous 67.5     .   ... 28.100      0.82193 0.605590
# 28   Case Non-synonymous    77.7     .   ... 22.500      0.62575 0.278120
# 29   Case Non-synonymous    82.2     .   ... 22.200      0.35252 0.159260
# 30   Case Non-synonymous    51.2     .   ... 25.900      0.71167 0.255720
# ...  ...                    ...      ...     ...         ...     ...
# 4796 Case Non-synonymous    N/A      .   ... 15.400      1.07700 0.648690
# 4797 Case Non-synonymous    52.6     .   ... 19.860      0.97964 1.200300
# 4798 Control Non-synonymous N/A      .   ...  0.023      1.05400 0.695390
# 4799 Control Non-synonymous 34.1     .   ... 10.050      0.97132 1.239700
# 4800 Control Synonymous     34.1     .   ...  7.793      0.97132 1.239700
# 4801 Control Non-synonymous 34.1     .   ... 20.100      0.97132 1.239700
# 4802 Control Non-synonymous 45.5     .   ... 32.000      1.05500 0.777230
# 4803 Case Non-synonymous    N/A      .   ... 18.920      0.96207 0.727550
# 4804 Control Non-synonymous 29.3     .   ...  8.113      1.18320 0.795340
# 4805 Case Non-synonymous    N/A      .   ... 24.400      0.96543 0.365300
# 4806 Case Non-synonymous    38.6     .   ... 14.770      1.12490 0.650370
# 4807 Case Non-synonymous    N/A      .   ... 24.200      0.82214 0.819950
# 4808 Control Non-synonymous 57.4     .   ... 26.000      0.92104 0.337430
# 4809 Control Non-synonymous N/A      .   ... 17.240      0.89638       NA
# 4810 Case Non-synonymous    N/A      .   ... 18.260      0.69283 0.319640
# 4811 Case Non-synonymous    N/A      .   ... 21.400      0.85926 0.457410
# 4812 Case Non-synonymous    65.6     .   ...  0.001      0.77832 0.158520
# 4813 Case Non-synonymous    65.6     .   ... 29.000      0.77832 0.158520
# 4814 Control Non-synonymous 17.8     .   ... 19.070      0.97311 0.990210
# 4815 Case Synonymous        N/A      .   ...  0.037      1.20270 0.958710
# 4816 Case Non-synonymous    46       .   ... 20.400      0.69923 0.562450
# 4817 Case Synonymous        44.5     .   ...  4.108      1.01530 0.484640
# 4818 Case Non-synonymous    42.8     .   ... 10.090      0.84340 0.326660
# 4819 Control Non-synonymous 60       .   ... 22.000      0.74407 0.368120
# 4820 Case Non-synonymous    56.2     .   ... 17.920      0.50875 0.000000
# 4821 Control Synonymous     56.2     .   ... 10.170      0.50875 0.000000
# 4822 Case Non-synonymous    92.9     .   ... 24.500      0.56157 0.063091
# 4823 Case Non-synonymous    60.8     .   ... 21.200      0.93871 0.323840
# 4824 Control Non-synonymous 60.8     .   ... 25.300      0.93871 0.323840
# 4825 Control Non-synonymous 17.3     .   ... 25.700      0.82006 0.683780
#      oe_syn  pLI         oe      dnv_node_degree corrected_dnv_node_degree
# 1    0.87995  4.5229e-11 0.81065  14             0.16091954
# 2    0.97190  2.4356e-13 1.05910  47             1.00000000
# 3    0.93551  9.1275e-17 0.97211   0                    NaN
# 4    0.96954  1.0000e+00 0.67376   7             1.00000000
# 5    0.97252  7.6172e-01 0.69331   1             0.08333333
# 6    0.96105  2.3101e-12 0.96105   0             0.00000000
# 7    1.07510  6.3216e-03 0.90591   1             1.00000000
# 8    1.03200  2.9220e-15 0.87450   0             0.00000000
# 9    1.03200  2.9220e-15 0.87450   0             0.00000000
# 10   1.04120 8.7753e-114 1.08650   2             1.00000000
# 11   1.04120 8.7753e-114 1.08650   2             1.00000000
# 12   1.04120 8.7753e-114 1.08650   2             1.00000000
# 13   1.04120 8.7753e-114 1.04120   2             1.00000000
# 14   1.16190  6.6226e-08 0.97157   0             0.00000000
# 15   1.08960  5.3499e-48 1.05260   4             1.00000000
# 16   1.08960  5.3499e-48 1.05260   4             1.00000000
# 17   1.05500  2.1111e-55 1.11210   1             1.00000000
# 18   0.95187  1.6090e-52 1.01860   0                    NaN
# 19   0.95187  1.6090e-52 0.95187   0                    NaN
# 20   1.14580  1.5612e-12 0.88341   0             0.00000000
# 21   1.13770  8.5999e-19 1.01750  11             1.00000000
# 22   1.12150  1.1727e-03 1.12150   1             0.04545455
# 23   1.02140  3.9884e-46 1.01970   0                    NaN
# 24   1.02950  5.2025e-47 1.09990   3             1.00000000
# 25   0.89672  1.2092e-26 0.71149   3             1.00000000
# 26   1.07230  5.6167e-35 1.07230   0             0.00000000
# 27   1.05510  7.9571e-24 0.82193   5             0.35714286
# 28   0.90569  7.8364e-03 0.62575  12             1.00000000
# 29   0.88432  9.7380e-01 0.35252 131             1.00000000
# 30   0.96158  1.1182e-01 0.71167   1             1.00000000
# ...  ...     ...         ...     ...             ...
# 4796 1.05950 8.2354e-05  1.07700 24              1.00000000
# 4797 1.00510 9.2466e-06  1.20030  2              1.00000000
# 4798 1.10120 4.5580e-03  1.05400  1              0.16666667
# 4799 1.07680 1.5554e-06  0.97132  1              1.00000000
# 4800 1.07680 1.5554e-06  1.07680  1              1.00000000
# 4801 1.07680 1.5554e-06  0.97132  1              1.00000000
# 4802 1.11680 3.2592e-03  1.05500  0                     NaN
# 4803 0.94489 4.2150e-10  0.96207  0                     NaN
# 4804 1.15900 2.3543e-12  1.18320  1              0.09090909
# 4805 1.10210 6.9622e-03  0.96543  4              1.00000000
# 4806 1.09190 4.4817e-02  1.12490  0                     NaN
# 4807 0.81926 5.8965e-11  0.82214  3              1.00000000
# 4808 1.17330 5.9572e-02  0.92104  1              0.11111111
# 4809 0.76417         NA  0.89638  0              0.00000000
# 4810 0.75576 1.7819e-03  0.69283  0                     NaN
# 4811 0.82492 8.1539e-02  0.85926  0                     NaN
# 4812 1.03500 9.9983e-01  0.77832  9              1.00000000
# 4813 1.03500 9.9983e-01  0.77832  9              1.00000000
# 4814 1.05610 1.8672e-21  0.99021  1              0.33333333
# 4815 1.19000 1.7419e-18  1.19000  1              0.20000000
# 4816 0.69271 2.1145e-07  0.69923  0                     NaN
# 4817 1.19950 3.5648e-05  1.19950  1              1.00000000
# 4818 0.96313 4.8141e-04  0.84340  1              1.00000000
# 4819 0.91445 7.9168e-05  0.74407  0                     NaN
# 4820 0.88890 1.0000e+00  0.50875  0                     NaN
# 4821 0.88890 1.0000e+00  0.88890  0                     NaN
# 4822 0.97826 1.0000e+00  0.56157  6              1.00000000
# 4823 0.89958 1.4855e-03  0.93871 56              1.00000000
# 4824 0.89958 1.4855e-03  0.93871 56              1.00000000
# 4825 0.78605 1.2573e-11  0.82006  0                     NaN
#      chd_node_degree corrected_chd_node_degree
# 1     1              0.011494253
# 2     0              0.000000000
# 3     0                      NaN
# 4     0              0.000000000
# 5     0              0.000000000
# 6     0              0.000000000
# 7     0              0.000000000
# 8     0              0.000000000
# 9     0              0.000000000
# 10    0              0.000000000
# 11    0              0.000000000
# 12    0              0.000000000
# 13    0              0.000000000
# 14    0              0.000000000
# 15    0              0.000000000
# 16    0              0.000000000
# 17    0              0.000000000
# 18    0                      NaN
# 19    0                      NaN
# 20    0              0.000000000
# 21    0              0.000000000
# 22    0              0.000000000
# 23    0                      NaN
# 24    0              0.000000000
# 25    0              0.000000000
# 26    0              0.000000000
# 27    1              0.071428571
# 28   12              1.000000000
# 29    1              0.007633588
# 30    0              0.000000000
# ...  ...             ...
# 4796 1               0.04166667
# 4797 0               0.00000000
# 4798 0               0.00000000
# 4799 0               0.00000000
# 4800 0               0.00000000
# 4801 0               0.00000000
# 4802 0                      NaN
# 4803 0                      NaN
# 4804 0               0.00000000
# 4805 0               0.00000000
# 4806 0                      NaN
# 4807 0               0.00000000
# 4808 0               0.00000000
# 4809 0               0.00000000
# 4810 0                      NaN
# 4811 0                      NaN
# 4812 1               0.11111111
# 4813 1               0.11111111
# 4814 0               0.00000000
# 4815 0               0.00000000
# 4816 0                      NaN
# 4817 1               1.00000000
# 4818 0               0.00000000
# 4819 0                      NaN
# 4820 0                      NaN
# 4821 0                      NaN
# 4822 0               0.00000000
# 4823 2               0.03571429
# 4824 2               0.03571429
# 4825 0                      NaN

# %% [markdown]
# ## Save out table of characteristics for manuscript

# %%
write.table(df, file = "../manuscript/tables/variant_characteristics.tsv", sep="\t",
           quote=FALSE, row.names = FALSE)

# %% [markdown]
# ## Calculating connectivity of reference gene not in interactome: NKX2-5

# %%
get_degree <- function(gene, subnetwork){
    
    lines = subnetwork[which(subnetwork$aliasA == gene | subnetwork$aliasB == gene),]
    lines = lines[which(lines$aliasA != lines$aliasB),c('aliasA','aliasB')]
    swap_lines = lines[,c('aliasB','aliasA')]
    names(swap_lines) = c('aliasA','aliasB')
    both = rbind(lines, swap_lines)
    both = unique(both)
    degree = nrow(both)/2
    
    return(degree)
}

# %%
#Create data table to save overall connectivity of each interactome gene
gene_conn = data.frame(Gene = c("NKX2-5", "MKL2", "MYH7"))
gene_conn$total_connections = 0
gene_conn$dnv_node_degree = 0
gene_conn$corrected_dnv_node_degree = 0
gene_conn$chd_node_degree = 0
gene_conn$corrected_chd_node_degree = 0


for (i in c(1:nrow(gene_conn))){
    degree = get_degree(gene_conn$Gene[i], iref)
    gene_conn$total_connections[i] = degree
    
    first_interactome = iref[which(iref$aliasA %in% nonsyn_dnvs | iref$aliasB %in% nonsyn_dnvs),]
    dnv_degree = get_degree(gene_conn$Gene[i], first_interactome)
    gene_conn$dnv_node_degree[i] = dnv_degree
    gene_conn$corrected_dnv_node_degree[i] = dnv_degree/gene_conn$total_connections[i]
    
    first_interactome = iref[which(iref$aliasA %in% known_genes | iref$aliasB %in% known_genes),]
    chd_degree = get_degree(gene_conn$Gene[i], first_interactome)
    gene_conn$chd_node_degree[i] = chd_degree
    gene_conn$corrected_chd_node_degree[i] = chd_degree/gene_conn$total_connections[i]
}

gene_conn
# Out:
#   Gene   total_connections dnv_node_degree corrected_dnv_node_degree
# 1 NKX2-5  9                3               0.3333333
# 2 MKL2    6                0               0.0000000
# 3 MYH7   19                2               0.1052632
#   chd_node_degree corrected_chd_node_degree
# 1 9               1
# 2 0               0
# 3 0               0
