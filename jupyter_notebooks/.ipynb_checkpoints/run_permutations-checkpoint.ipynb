# %%
import os
import sys
import pickle
import random
import numpy as np
import pandas as pd
from collections import defaultdict

import matplotlib.pyplot as plt
import seaborn as sns

n_perm = 1000
random.seed(42)

# Total number of individuals sequenced in each group (according to publication)
#n_case_trios = 2645 # Nature Genetics cohort
n_case_trios = 3509 # + v11 cohort
n_ctrl_trios = 1789

# %% [markdown]
# ## Functions to load data

# %%
def load_interactome(interactome_name):
    gene_file = "../intermediate/interactome_lists/{}_genes.txt".format(interactome_name)
    gene_list = []
    
    with open(gene_file) as f:
        for line in f:
            gene_list.append(line.strip())
            
    return gene_list



def load_variants_as_dict(variant_filename, mutation_str_list, unknown_only = False):
    
    variant_dict = defaultdict(list)
    with open(variant_filename, encoding='utf-8-sig') as f:
        
        first_line = f.readline().split(',')
        pid_idx = next(x for x,val in enumerate(first_line) if val in ['Blinded.ID', 'Blinded ID'])
        gene_idx = next(x for x,val in enumerate(first_line) if val == "Gene")
        class_idx = next(x for x,val in enumerate(first_line) if val in ['Variant.Class', 'Variant_Class', 
                                                                         'Variant Class', 'Func.refGene'])
        next(f)
        
        for line in f:
            line_array = line.split(',')
            
            # Ignore if it's a known gene and we're only analyzing unknown
            if unknown_only==True:
                if line_array[gene_idx] in known_genes:
                    continue
            # Only save to dictionary if it's in the type of variants we're analyzing
            if line_array[class_idx] in mutation_str_list:
                variant_dict[line_array[pid_idx]].append(line_array[gene_idx])
                
    return variant_dict


# Add empty placeholders for individuals with no called de novos in either category
def add_placeholders(variant_dict, expected_n):
    
    if len(variant_dict) < expected_n:
        n_placeholders = expected_n - len(variant_dict)
        ids = range(0,n_placeholders)
        for i in ids:
            variant_dict["placeholder{}".format(i)] = ([],[])

    return(variant_dict)
    
def combine_id_dicts(nonsynonymous_dict, synonymous_dict, expected_n):
    id_list = [nonsynonymous_dict.keys(), synonymous_dict.keys()]
    ids_with_data = set([item for sublist in id_list for item in sublist])
    new_dict = {}
    
    for pid in ids_with_data:
        if pid not in nonsynonymous_dict:
            nonsynonymous_dict[pid] = []
        elif pid not in synonymous_dict:
            synonymous_dict[pid] = []
        new_dict[pid] = (nonsynonymous_dict[pid], synonymous_dict[pid])
    
    variant_dict = add_placeholders(new_dict, expected_n)
    return variant_dict

# %% [markdown]
# ## Functions to randomly shuffle case-control status

# %%
# Random shuffle using numpy
def shuffle_dict_keys(a):
    keys = list(a.keys())
    np.random.shuffle(keys)
    b = dict(zip(keys, a.values()))
    return(b)


# Scramble the IDs from the case and control dictionaries
def scramble_ids(case_dict, ctrl_dict):
    
    combined_dict = {**case_dict, **ctrl_dict} 
    scrambled_dict = shuffle_dict_keys(combined_dict)
    
    case_ids = []
    ctrl_ids = []
    for key in combined_dict:
        if key.startswith("1-") or key.startswith("GT"):
            case_ids.append(key)
        else:
            ctrl_ids.append(key)
    
    scram_case = {k: scrambled_dict[k] for k in case_ids}
    scram_ctrl = {k: scrambled_dict[k] for k in ctrl_ids}
    
    return(scram_case, scram_ctrl)

    
# Function to return n permuted odds ratios
def permute_case_ctrl(case_dict, ctrl_dict, gene_list, n_perm):
    
    perm_list = []
    contingency_list = []
    
    for i in range(0,n_perm):
        scram_case, scram_ctrl = scramble_ids(case_dict, ctrl_dict)
        contingency = get_OR(scram_case, scram_ctrl, gene_list)
        contingency_list.append(contingency)
        perm_list.append(contingency[5])
        
    contingency_df = pd.DataFrame(contingency_list, 
                                  columns=['case_intact_count', 'case_nonintact_count', 
                                           'ctrl_intact_count', 'ctrl_nonintact_count', 
                                           'OR', 'synonymous-corrected OR'])
        
    return(perm_list, contingency_df)
    
    
# Function to calculate p-value from list of permutation results
def get_permutation_pval(perm_list, true_OR):
    
    nGreater = len([num for num in perm_list if num > true_OR])
    pval = nGreater/len(perm_list)
    minp = 1/len(perm_list)
    
    if nGreater == 0:
        pval = "<{}".format(minp)
        
    return(pval)

# %% [markdown]
# ## Functions to run permutations

# %%
# Functions to calculate odds ratio
def get_OR(case_dict, ctrl_dict, gene_list, truth = False):
    
    case_ct, case_non_ct = get_ctable(case_dict, gene_list)
    ctrl_ct, ctrl_non_ct = get_ctable(ctrl_dict, gene_list)
                
    # Add pseudocount if any values are equal to zero
    if 0 in [case_ct, case_non_ct, ctrl_ct, ctrl_non_ct]:
        case_ct+=0.5; case_non_ct+=0.5; ctrl_ct+=0.5; ctrl_non_ct+=0.5;
        
    # Calculate odds ratio
    odds = (case_ct * ctrl_non_ct) / (ctrl_ct * case_non_ct)
    
    # Calculate the synonymous correction, and print it out
    syn_case_ct, syn_case_non_ct = get_ctable(case_dict, gene_list, var_type="synonymous")
    syn_ctrl_ct, syn_ctrl_non_ct = get_ctable(ctrl_dict, gene_list, var_type="synonymous")
    # Add pseudocount if any values are equal to zero
    if 0 in [syn_case_ct, syn_case_non_ct, syn_ctrl_ct, syn_ctrl_non_ct]:
        syn_case_ct+=0.5; syn_case_non_ct+=0.5; syn_ctrl_ct+=0.5; syn_ctrl_non_ct+=0.5;
    syn_odds = (syn_case_ct * syn_ctrl_non_ct) / (syn_ctrl_ct * syn_case_non_ct)
    corrected_odds = odds * 1/syn_odds
        
    # Print contingency table, to look at true OR numbers
    if truth == True:
        print("Case interactome muts: {}".format(case_ct))
        print("Case non-interactome muts: {}".format(case_non_ct))
        print("Ctrl interactome muts: {}".format(ctrl_ct))
        print("Ctrl non-interactome muts: {}".format(ctrl_non_ct))
        print("Odds ratio: {}".format(odds))
        
        print("Synonymous OR: ", syn_odds)
        print("Corrected OR: ", corrected_odds)
        
    return (case_ct, case_non_ct, ctrl_ct, ctrl_non_ct, odds, corrected_odds)



# Function to iterate through dictionary, returning contingency table
def get_ctable(dictionary, gene_list, var_type="non-synonymous"):
    yes_ct = 0; no_ct = 0
    
    if var_type=="non-synonymous":
        idx=0
    else:
        idx=1
    
    # Create contingency table - get yes and no values
    for indi in dictionary:
        
        for genes in dictionary[indi][idx]:

            if (genes in gene_list):
                yes_ct += 1
            else:
                no_ct += 1
                
    return(yes_ct, no_ct)



def get_summary_stats(contingency_df):
        
    perm_list_original = list(contingency_df['OR'])
    perm_list_corrected = list(contingency_df['synonymous-corrected OR'])
    
    OR_original = perm_list_original.pop()
    OR_corrected = perm_list_corrected.pop()
    
    pval_original = get_permutation_pval(perm_list_original, OR_original)
    pval_corrected = get_permutation_pval(perm_list_corrected, OR_corrected)
    
    return [(perm_list_original, OR_original, pval_original), 
            (perm_list_corrected, OR_corrected, pval_corrected)]

# %% [markdown]
# ## Main

# %%
# Known CHD-associated genes
fname = "../data/databases/known_CHD_genes.txt"
known_genes = []
with open(fname) as f:
    for line in f:
        known_genes.append(line.strip())

# %%
def permutation_routine(interactome_name, case_filename, ctrl_filename, variant_str, mut_type, cell_type):
    
    print("Interactome: ", interactome_name)
    interactome_dict = {}

    interactome = load_interactome(interactome_name)
    
    # Print odds ratios and pvalues, save permuted odds ratios for all genes/unknown genes
    for unknown in [True, False]:

        if unknown == True:
            known_str = 'unknownGenes'
        else:
            known_str = 'allGenes'

            
        # Get dictionaries of variants
        case_nonsyn_dict = load_variants_as_dict(case_filename, variant_str, unknown_only = unknown)
        ctrl_nonsyn_dict = load_variants_as_dict(ctrl_filename,variant_str, unknown_only = unknown)
        case_syn_dict = load_variants_as_dict(case_filename, ['syn'], unknown_only = unknown)
        ctrl_syn_dict = load_variants_as_dict(ctrl_filename, ['syn'], unknown_only = unknown)

        print("Number of case trios: ", n_case_trios)
        proband_dict = combine_id_dicts(case_nonsyn_dict, case_syn_dict, n_case_trios)
        control_dict = combine_id_dicts(ctrl_nonsyn_dict, ctrl_syn_dict, n_ctrl_trios)

        # Get true odds ratio
        contingency = get_OR(proband_dict, control_dict, interactome, truth=True)
        true_OR = contingency[4]
        fixed_OR = contingency[5]

        
        # Permute case/control status and read out results
        perm_list, contingency_df = permute_case_ctrl(proband_dict, control_dict,interactome,n_perm)
        contingency_df = contingency_df.rename('Perm{}'.format)
        contingency_df.loc[len(contingency_df)] = contingency
        contingency_df.rename({contingency_df.index[-1]: "True"}, inplace=True)
        print(contingency_df)
        

        
        # Get summary stats
        summary_stats = get_summary_stats(contingency_df)
        original_list_or_pval = summary_stats[0]
        corrected_list_or_pval = summary_stats[1]

        dict_str = '{}_{}_{}_{}_original'.format(interactome_name, cell_type, mut_type, known_str)
        interactome_dict[dict_str] = {"OR":summary_stats[0][1], "PVAL":summary_stats[0][2], "true_counts":contingency_df.loc['True',:].tolist()}
        dict_str = '{}_{}_{}_{}_syn-corrected'.format(interactome_name, cell_type, mut_type, known_str)
        interactome_dict[dict_str] = {"OR":summary_stats[1][1], "PVAL":summary_stats[1][2], "true_counts":contingency_df.loc['True',:].tolist()}


    return(interactome_dict)

# %%
# Get results for rare inherited loss-of-function variants
case_filename = '../data/variants/LoF_cases.csv'
ctrl_filename = '../data/variants/LoF_ctrls.csv' 
cell_type = 'cardiac progenitor'
variant_str = ['exonic','splice']
mut_type = 'lof-inherited'

results_dict = permutation_routine("GATA4", case_filename, ctrl_filename, variant_str, mut_type, cell_type)
results_dict.update(permutation_routine("TBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
results_dict.update(permutation_routine("GATA4-TBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
# Out:
# Interactome:  GATA4
# Case interactome muts: 59
# Case non-interactome muts: 9636
# Ctrl interactome muts: 48
# Ctrl non-interactome muts: 10314
# Odds ratio: 1.3156522415940224
# Synonymous OR:  1.0
# Corrected OR:  1.3156522415940224
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 38.0                7950.0               69.0
# Perm1                 48.0                8015.0               59.0
# Perm2                 43.0                7865.0               64.0
# Perm3                 39.0                8056.0               68.0
# Perm4                 45.0                7805.0               62.0
# ...                    ...                   ...                ...
# Perm996               47.0                8117.0               60.0
# Perm997               44.0                8010.0               63.0
# Perm998               45.0                8072.0               62.0
# Perm999               45.0                7958.0               62.0
# True                  59.0                9636.0               48.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 12000.0  0.831282                 0.831282
# Perm1                 11935.0  1.211457                 1.211457
# Perm2                 12085.0  1.032372                 1.032372
# Perm3                 11894.0  0.846767                 0.846767
# Perm4                 12145.0  1.129394                 1.129394
# ...                       ...       ...                      ...
# Perm996               11833.0  1.141947                 1.141947
# Perm997               11940.0  1.041080                 1.041080
# Perm998               11878.0  1.068029                 1.068029
# Perm999               11992.0  1.093726                 1.093726
# True                  10314.0  1.315652                 1.315652
#
# [1001 rows x 6 columns]
# Case interactome muts: 64
# Case non-interactome muts: 9819
# Ctrl interactome muts: 52
# Ctrl non-interactome muts: 10469
# Odds ratio: 1.312243922693052
# Synonymous OR:  1.0
# Corrected OR:  1.312243922693052
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 42.0                8002.0               74.0
# Perm1                 45.0                8175.0               71.0
# Perm2                 43.0                8006.0               73.0
# Perm3                 49.0                8133.0               67.0
# Perm4                 41.0                8020.0               75.0
# ...                    ...                   ...                ...
# Perm996               39.0                8097.0               77.0
# Perm997               38.0                8021.0               78.0
# Perm998               55.0                8120.0               61.0
# Perm999               49.0                8091.0               67.0
# True                  64.0                9819.0               52.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 12286.0  0.871424                 0.871424
# Perm1                 12113.0  0.939114                 0.939114
# Perm2                 12282.0  0.903648                 0.903648
# Perm3                 12155.0  1.093013                 1.093013
# Perm4                 12268.0  0.836223                 0.836223
# ...                       ...       ...                      ...
# Perm996               12191.0  0.762586                 0.762586
# Perm997               12267.0  0.745073                 0.745073
# Perm998               12168.0  1.351127                 1.351127
# Perm999               12197.0  1.102484                 1.102484
# True                  10469.0  1.312244                 1.312244
#
# [1001 rows x 6 columns]
# Interactome:  TBX5
# Case interactome muts: 20
# Case non-interactome muts: 9675
# Ctrl interactome muts: 21
# Ctrl non-interactome muts: 10341
# Odds ratio: 1.0179401993355481
# Synonymous OR:  1.0
# Corrected OR:  1.0179401993355481
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 13.0                8134.0               28.0
# Perm1                 14.0                7888.0               27.0
# Perm2                 15.0                7924.0               26.0
# Perm3                 17.0                8040.0               24.0
# Perm4                 14.0                7865.0               27.0
# ...                    ...                   ...                ...
# Perm996               11.0                8036.0               30.0
# Perm997               16.0                8079.0               25.0
# Perm998                9.0                8122.0               32.0
# Perm999               21.0                7783.0               20.0
# True                  20.0                9675.0               21.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 11882.0  0.678220                 0.678220
# Perm1                 12128.0  0.797235                 0.797235
# Perm2                 12092.0  0.880383                 0.880383
# Perm3                 11976.0  1.055100                 1.055100
# Perm4                 12151.0  0.801083                 0.801083
# ...                       ...       ...                      ...
# Perm996               11980.0  0.546624                 0.546624
# Perm997               11937.0  0.945622                 0.945622
# Perm998               11894.0  0.411867                 0.411867
# Perm999               12233.0  1.650347                 1.650347
# True                  10341.0  1.017940                 1.017940
#
# [1001 rows x 6 columns]
# Case interactome muts: 20
# Case non-interactome muts: 9863
# Ctrl interactome muts: 21
# Ctrl non-interactome muts: 10500
# Odds ratio: 1.0138902970698571
# Synonymous OR:  1.0
# Corrected OR:  1.0138902970698571
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 21.0                8131.0               20.0
# Perm1                 14.0                8145.0               27.0
# Perm2                 14.0                8088.0               27.0
# Perm3                 12.0                8008.0               29.0
# Perm4                 15.0                8130.0               26.0
# ...                    ...                   ...                ...
# Perm996               15.0                8160.0               26.0
# Perm997               18.0                8182.0               23.0
# Perm998               21.0                8198.0               20.0
# Perm999               18.0                8048.0               23.0
# True                  20.0                9863.0               21.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 12232.0  1.579584                 1.579584
# Perm1                 12218.0  0.777810                 0.777810
# Perm2                 12275.0  0.786945                 0.786945
# Perm3                 12355.0  0.638413                 0.638413
# Perm4                 12233.0  0.868081                 0.868081
# ...                       ...       ...                      ...
# Perm996               12203.0  0.862769                 0.862769
# Perm997               12181.0  1.165113                 1.165113
# Perm998               12165.0  1.558093                 1.558093
# Perm999               12315.0  1.197543                 1.197543
# True                  10500.0  1.013890                 1.013890
#
# [1001 rows x 6 columns]
# Interactome:  GATA4-TBX5
# Case interactome muts: 70
# Case non-interactome muts: 9625
# Ctrl interactome muts: 65
# Ctrl non-interactome muts: 10297
# Odds ratio: 1.1521118881118881
# Synonymous OR:  1.0
# Corrected OR:  1.1521118881118881
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 52.0                7879.0               83.0
# Perm1                 53.0                7866.0               82.0
# Perm2                 67.0                8020.0               68.0
# Perm3                 51.0                7885.0               84.0
# Perm4                 57.0                7880.0               78.0
# ...                    ...                   ...                ...
# Perm996               55.0                8096.0               80.0
# Perm997               52.0                8034.0               83.0
# Perm998               55.0                7965.0               80.0
# Perm999               43.0                7914.0               92.0
# True                  70.0                9625.0               65.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 12043.0  0.957610                 0.957610
# Perm1                 12056.0  0.990630                 0.990630
# Perm2                 11902.0  1.462216                 1.462216
# Perm3                 12037.0  0.926846                 0.926846
# Perm4                 12042.0  1.116742                 1.116742
# ...                       ...       ...                      ...
# Perm996               11826.0  1.004246                 1.004246
# Perm997               11888.0  0.927048                 0.927048
# Perm998               11957.0  1.032070                 1.032070
# Perm999               12008.0  0.709178                 0.709178
# True                  10297.0  1.152112                 1.152112
#
# [1001 rows x 6 columns]
# Case interactome muts: 75
# Case non-interactome muts: 9808
# Ctrl interactome muts: 69
# Ctrl non-interactome muts: 10452
# Odds ratio: 1.1583268316901907
# Synonymous OR:  1.0
# Corrected OR:  1.1583268316901907
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 55.0                7908.0               89.0
# Perm1                 51.0                8139.0               93.0
# Perm2                 62.0                8099.0               82.0
# Perm3                 57.0                8181.0               87.0
# Perm4                 62.0                8037.0               82.0
# ...                    ...                   ...                ...
# Perm996               63.0                8096.0               81.0
# Perm997               63.0                7984.0               81.0
# Perm998               57.0                8075.0               87.0
# Perm999               61.0                8154.0               83.0
# True                  75.0                9808.0               69.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 12352.0  0.965258                 0.965258
# Perm1                 12121.0  0.816685                 0.816685
# Perm2                 12161.0  1.135313                 1.135313
# Perm3                 12079.0  0.967342                 0.967342
# Perm4                 12223.0  1.149904                 1.149904
# ...                       ...       ...                      ...
# Perm996               12164.0  1.168588                 1.168588
# Perm997               12276.0  1.195892                 1.195892
# Perm998               12185.0  0.988641                 0.988641
# Perm999               12106.0  1.091143                 1.091143
# True                  10452.0  1.158327                 1.158327
#
# [1001 rows x 6 columns]

# %%
results_dict
# Out:
# {'GATA4_cardiac progenitor_lof-inherited_unknownGenes_original': {'OR': 1.3156522415940224,
#   'PVAL': 0.076,
#   'true_counts': [59.0,
#    9636.0,
#    48.0,
#    10314.0,
#    1.3156522415940224,
#    1.3156522415940224]},
#  'GATA4_cardiac progenitor_lof-inherited_unknownGenes_syn-corrected': {'OR': 1.3156522415940224,
#   'PVAL': 0.076,
#   'true_counts': [59.0,
#    9636.0,
#    48.0,
#    10314.0,
#    1.3156522415940224,
#    1.3156522415940224]},
#  'GATA4_cardiac progenitor_lof-inherited_allGenes_original': {'OR': 1.312243922693052,
#   'PVAL': 0.077,
#   'true_counts': [64.0,
#    9819.0,
#    52.0,
#    10469.0,
#    1.312243922693052,
#    1.312243922693052]},
#  'GATA4_cardiac progenitor_lof-inherited_allGenes_syn-corrected': {'OR': 1.312243922693052,
#   'PVAL': 0.077,
#   'true_counts': [64.0,
#    9819.0,
#    52.0,
#    10469.0,
#    1.312243922693052,
#    1.312243922693052]},
#  'TBX5_cardiac progenitor_lof-inherited_unknownGenes_original': {'OR': 1.0179401993355481,
#   'PVAL': 0.494,
#   'true_counts': [20.0,
#    9675.0,
#    21.0,
#    10341.0,
#    1.0179401993355481,
#    1.0179401993355481]},
#  'TBX5_cardiac progenitor_lof-inherited_unknownGenes_syn-corrected': {'OR': 1.0179401993355481,
#   'PVAL': 0.494,
#   'true_counts': [20.0,
#    9675.0,
#    21.0,
#    10341.0,
#    1.0179401993355481,
#    1.0179401993355481]},
#  'TBX5_cardiac progenitor_lof-inherited_allGenes_original': {'OR': 1.0138902970698571,
#   'PVAL': 0.466,
#   'true_counts': [20.0,
#    9863.0,
#    21.0,
#    10500.0,
#    1.0138902970698571,
#    1.0138902970698571]},
#  'TBX5_cardiac progenitor_lof-inherited_allGenes_syn-corrected': {'OR': 1.0138902970698571,
#   'PVAL': 0.466,
#   'true_counts': [20.0,
#    9863.0,
#    21.0,
#    10500.0,
#    1.0138902970698571,
#    1.0138902970698571]},
#  'GATA4-TBX5_cardiac progenitor_lof-inherited_unknownGenes_original': {'OR': 1.1521118881118881,
#   'PVAL': 0.195,
#   'true_counts': [70.0,
#    9625.0,
#    65.0,
#    10297.0,
#    1.1521118881118881,
#    1.1521118881118881]},
#  'GATA4-TBX5_cardiac progenitor_lof-inherited_unknownGenes_syn-corrected': {'OR': 1.1521118881118881,
#   'PVAL': 0.195,
#   'true_counts': [70.0,
#    9625.0,
#    65.0,
#    10297.0,
#    1.1521118881118881,
#    1.1521118881118881]},
#  'GATA4-TBX5_cardiac progenitor_lof-inherited_allGenes_original': {'OR': 1.1583268316901907,
#   'PVAL': 0.189,
#   'true_counts': [75.0,
#    9808.0,
#    69.0,
#    10452.0,
#    1.1583268316901907,
#    1.1583268316901907]},
#  'GATA4-TBX5_cardiac progenitor_lof-inherited_allGenes_syn-corrected': {'OR': 1.1583268316901907,
#   'PVAL': 0.189,
#   'true_counts': [75.0,
#    9808.0,
#    69.0,
#    10452.0,
#    1.1583268316901907,
#    1.1583268316901907]}}

# %%
# Run permutations for cardiac progenitor interactomes
#case_filename = '../data/variants/DNV_cases.csv'

nb_path = '/pollard/home/mpittman/lab_notebooks' 
for dnv_subset in ['inner_join_dnvs','outer_join_dnvs','outer_nonFSfilt_dnvs']:
    case_filename = '{}/{}.csv'.format(nb_path, dnv_subset)
    ctrl_filename = '../data/variants/DNV_ctrls.csv' 
    cell_type = 'cardiac progenitor'


    # Check that synonymous variants behave as expected
    variant_str = ['syn','synonymous']
    mut_type = 'synonymous-dnv'

    res_dict = results_dict.copy()
    res_dict.update(permutation_routine("GATA4", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
    res_dict.update(permutation_routine("TBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
    res_dict.update(permutation_routine("GATA4-TBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))


    # Get results for non-synonymous variants
    mut_dict = {'nonsynonymous-dnv':['non','frameshift','startloss','stoploss','misD',
                                     'splice','mis', 'loss', 'loss of function', 'non-frameshift'],
               'missense-dnv':['mis','misD'],
               'LoF-dnv':['non','frameshift','startloss','loss','loss of function'],
               'splice-dnv':['splice']}
    
    for mut_type in mut_dict:
        variant_str = mut_dict[mut_type]

        res_dict.update(permutation_routine("GATA4", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
        res_dict.update(permutation_routine("TBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
        res_dict.update(permutation_routine("GATA4-TBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))


    line_list = []
    for key in res_dict:
        interactome_name, cell_type, mut_type, known_str, correction = key.split('_')
        OR = res_dict[key]['OR']
        #pval = res_dict[key]['PVAL']
        count_array = res_dict[key]['true_counts']
        line_list.append([interactome_name, cell_type, mut_type, known_str, correction, count_array[0],
                          count_array[1], count_array[2], count_array[3], count_array[4], count_array[5]])
        #, pval])

    data_df = pd.DataFrame(line_list, columns = ['Interactome','Cell Type','Variant Type', 
                                                 'Included Genes', 'Correction', 
                                                 'case_intact_count', 'case_nonintact_count',
                                                 'ctrl_intact_count', 'ctrl_nonintact_count',
                                                 'OR', 'synonymous-corrected OR'])#, 'P-value'])
    print(data_df)
    data_df.to_csv('/pollard/home/mpittman/lab_notebooks/permutation_tests/permres_{}_{}.csv'.format(cell_type, dnv_subset))
# Out:
# Interactome:  GATA4
# Case interactome muts: 9
# Case non-interactome muts: 959
# Ctrl interactome muts: 9
# Ctrl non-interactome muts: 467
# Odds ratio: 0.4869655891553702
# Synonymous OR:  0.4869655891553702
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  4.0                 246.0               14.0
# Perm1                  5.0                 356.0               13.0
# Perm2                  4.0                 268.0               14.0
# Perm3                  6.0                 357.0               12.0
# Perm4                  1.0                 233.0               17.0
# ...                    ...                   ...                ...
# Perm996                2.0                 229.0               16.0
# Perm997                5.0                 236.0               13.0
# Perm998                2.0                 253.0               16.0
# Perm999                3.0                 259.0               15.0
# True                   9.0                 959.0                9.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1180.0  1.370499                      1.0
# Perm1                  1070.0  1.156007                      1.0
# Perm2                  1158.0  1.234542                      1.0
# Perm3                  1069.0  1.497199                      1.0
# Perm4                  1193.0  0.301187                      1.0
# ...                       ...       ...                      ...
# Perm996                1197.0  0.653384                      1.0
# Perm997                1190.0  1.939374                      1.0
# Perm998                1173.0  0.579545                      1.0
# Perm999                1167.0  0.901158                      1.0
# True                    467.0  0.486966                      1.0
#
# [1001 rows x 6 columns]
# Case interactome muts: 12
# Case non-interactome muts: 984
# Ctrl interactome muts: 10
# Ctrl non-interactome muts: 474
# Odds ratio: 0.5780487804878048
# Synonymous OR:  0.5780487804878048
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  6.0                 281.0               16.0
# Perm1                  5.0                 265.0               17.0
# Perm2                  4.0                 265.0               18.0
# Perm3                  3.0                 276.0               19.0
# Perm4                  4.0                 270.0               18.0
# ...                    ...                   ...                ...
# Perm996                4.0                 266.0               18.0
# Perm997                2.0                 280.0               20.0
# Perm998                4.0                 288.0               18.0
# Perm999                5.0                 354.0               17.0
# True                  12.0                 984.0               10.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1177.0  1.570730                      1.0
# Perm1                  1193.0  1.324084                      1.0
# Perm2                  1193.0  1.000419                      1.0
# Perm3                  1182.0  0.676201                      1.0
# Perm4                  1188.0  0.977778                      1.0
# ...                       ...       ...                      ...
# Perm996                1192.0  0.995823                      1.0
# Perm997                1178.0  0.420714                      1.0
# Perm998                1170.0  0.902778                      1.0
# Perm999                1104.0  0.917248                      1.0
# True                    474.0  0.578049                      1.0
#
# [1001 rows x 6 columns]
# Interactome:  TBX5
# Case interactome muts: 5
# Case non-interactome muts: 963
# Ctrl interactome muts: 3
# Ctrl non-interactome muts: 473
# Odds ratio: 0.8186223606784354
# Synonymous OR:  0.8186223606784354
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  1.0                 282.0                7.0
# Perm1                  0.5                 270.5                8.5
# Perm2                  1.0                 247.0                7.0
# Perm3                  2.0                 353.0                6.0
# Perm4                  2.0                 266.0                6.0
# ...                    ...                   ...                ...
# Perm996                1.0                 254.0                7.0
# Perm997                3.0                 260.0                5.0
# Perm998                1.0                 249.0                7.0
# Perm999                2.0                 357.0                6.0
# True                   5.0                 963.0                3.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1154.0  0.584600                      1.0
# Perm1                  1166.5  0.253670                      1.0
# Perm2                  1189.0  0.687681                      1.0
# Perm3                  1083.0  1.022663                      1.0
# Perm4                  1170.0  1.466165                      1.0
# ...                       ...       ...                      ...
# Perm996                1182.0  0.664792                      1.0
# Perm997                1176.0  2.713846                      1.0
# Perm998                1187.0  0.681010                      1.0
# Perm999                1079.0  1.007470                      1.0
# True                    473.0  0.818622                      1.0
#
# [1001 rows x 6 columns]
# Case interactome muts: 5
# Case non-interactome muts: 991
# Ctrl interactome muts: 3
# Ctrl non-interactome muts: 481
# Odds ratio: 0.8089471913891692
# Synonymous OR:  0.8089471913891692
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  1.0                 276.0                7.0
# Perm1                  0.5                 255.5                8.5
# Perm2                  4.0                 243.0                4.0
# Perm3                  3.0                 392.0                5.0
# Perm4                  2.0                 263.0                6.0
# ...                    ...                   ...                ...
# Perm996                1.0                 275.0                7.0
# Perm997                2.0                 284.0                6.0
# Perm998                3.0                 274.0                5.0
# Perm999                2.0                 271.0                6.0
# True                   5.0                 991.0                3.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1196.0  0.619048                      1.0
# Perm1                  1217.5  0.280304                      1.0
# Perm2                  1229.0  5.057613                      1.0
# Perm3                  1080.0  1.653061                      1.0
# Perm4                  1209.0  1.532319                      1.0
# ...                       ...       ...                      ...
# Perm996                1197.0  0.621818                      1.0
# Perm997                1188.0  1.394366                      1.0
# Perm998                1198.0  2.623358                      1.0
# Perm999                1201.0  1.477245                      1.0
# True                    481.0  0.808947                      1.0
#
# [1001 rows x 6 columns]
# Interactome:  GATA4-TBX5
# Case interactome muts: 13
# Case non-interactome muts: 955
# Ctrl interactome muts: 11
# Ctrl non-interactome muts: 465
# Odds ratio: 0.575440266539743
# Synonymous OR:  0.575440266539743
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  7.0                 340.0               17.0
# Perm1                  5.0                 248.0               19.0
# Perm2                  3.0                 262.0               21.0
# Perm3                  6.0                 250.0               18.0
# Perm4                  4.0                 355.0               20.0
# ...                    ...                   ...                ...
# Perm996                4.0                 257.0               20.0
# Perm997                6.0                 283.0               18.0
# Perm998                3.0                 257.0               21.0
# Perm999                3.0                 244.0               21.0
# True                  13.0                 955.0               11.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1080.0  1.307958                      1.0
# Perm1                  1172.0  1.243633                      1.0
# Perm2                  1158.0  0.631407                      1.0
# Perm3                  1170.0  1.560000                      1.0
# Perm4                  1065.0  0.600000                      1.0
# ...                       ...       ...                      ...
# Perm996                1163.0  0.905058                      1.0
# Perm997                1137.0  1.339223                      1.0
# Perm998                1163.0  0.646470                      1.0
# Perm999                1176.0  0.688525                      1.0
# True                    465.0  0.575440                      1.0
#
# [1001 rows x 6 columns]
# Case interactome muts: 16
# Case non-interactome muts: 980
# Ctrl interactome muts: 12
# Ctrl non-interactome muts: 472
# Odds ratio: 0.6421768707482993
# Synonymous OR:  0.6421768707482993
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  7.0                 341.0               21.0
# Perm1                 10.0                 401.0               18.0
# Perm2                  5.0                 264.0               23.0
# Perm3                  4.0                 238.0               24.0
# Perm4                  2.0                 274.0               26.0
# ...                    ...                   ...                ...
# Perm996                6.0                 246.0               22.0
# Perm997                6.0                 279.0               22.0
# Perm998                2.0                 263.0               26.0
# Perm999                4.0                 278.0               24.0
# True                  16.0                 980.0               12.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1111.0  1.086022                      1.0
# Perm1                  1051.0  1.456082                      1.0
# Perm2                  1188.0  0.978261                      1.0
# Perm3                  1214.0  0.850140                      1.0
# Perm4                  1178.0  0.330713                      1.0
# ...                       ...       ...                      ...
# Perm996                1206.0  1.337029                      1.0
# Perm997                1173.0  1.146628                      1.0
# Perm998                1189.0  0.347763                      1.0
# Perm999                1174.0  0.703837                      1.0
# True                    472.0  0.642177                      1.0
#
# [1001 rows x 6 columns]
# Interactome:  GATA4
# Case interactome muts: 44
# Case non-interactome muts: 2676
# Ctrl interactome muts: 15
# Ctrl non-interactome muts: 1301
# Odds ratio: 1.426108619830593
# Synonymous OR:  0.4869655891553702
# Corrected OR:  2.9285613841917315
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 29.0                1837.0               30.0
# Perm1                 26.0                1935.0               33.0
# Perm2                 31.0                1914.0               28.0
# Perm3                 23.0                1875.0               36.0
# Perm4                 32.0                1850.0               27.0
# ...                    ...                   ...                ...
# Perm996               25.0                1845.0               34.0
# Perm997               25.0                1840.0               34.0
# Perm998               28.0                1935.0               31.0
# Perm999               30.0                1821.0               29.0
# True                  44.0                2676.0               15.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2140.0  1.126111                 0.626452
# Perm1                  2042.0  0.831446                 0.907032
# Perm2                  2063.0  1.193331                 1.220414
# Perm3                  2102.0  0.716237                 0.433270
# Perm4                  2127.0  1.362643                 0.826659
# ...                       ...       ...                      ...
# Perm996                2132.0  0.849673                 0.562360
# Perm997                2137.0  0.853980                 0.849203
# Perm998                2042.0  0.953172                 0.871288
# Perm999                2156.0  1.224791                 3.383159
# True                   1301.0  1.426109                 2.928561
#
# [1001 rows x 6 columns]
# Case interactome muts: 72
# Case non-interactome muts: 2829
# Ctrl interactome muts: 15
# Ctrl non-interactome muts: 1330
# Odds ratio: 2.256627783669141
# Synonymous OR:  0.5780487804878048
# Corrected OR:  3.9038708493854344
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 36.0                2023.0               51.0
# Perm1                 43.0                2064.0               44.0
# Perm2                 48.0                1965.0               39.0
# Perm3                 46.0                2055.0               41.0
# Perm4                 39.0                2034.0               48.0
# ...                    ...                   ...                ...
# Perm996               39.0                2020.0               48.0
# Perm997               44.0                1996.0               43.0
# Perm998               45.0                1973.0               42.0
# Perm999               48.0                1988.0               39.0
# True                  72.0                2829.0               15.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2136.0  0.745311                 0.807066
# Perm1                  2095.0  0.991951                 0.792231
# Perm2                  2194.0  1.374202                 0.881273
# Perm3                  2104.0  1.148703                 0.989295
# Perm4                  2125.0  0.848851                 0.451973
# ...                       ...       ...                      ...
# Perm996                2139.0  0.860365                 0.631860
# Perm997                2163.0  1.108869                 0.840476
# Perm998                2186.0  1.187097                 2.069194
# Perm999                2171.0  1.344064                 0.638744
# True                   1330.0  2.256628                 3.903871
#
# [1001 rows x 6 columns]
# Interactome:  TBX5
# Case interactome muts: 13
# Case non-interactome muts: 2707
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 1315
# Odds ratio: 6.315108976727004
# Synonymous OR:  0.8186223606784354
# Corrected OR:  7.7143128261159895
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  5.0                1877.0                9.0
# Perm1                  7.0                1896.0                7.0
# Perm2                  2.0                1929.0               12.0
# Perm3                  8.0                1915.0                6.0
# Perm4                  6.0                1827.0                8.0
# ...                    ...                   ...                ...
# Perm996                4.0                1867.0               10.0
# Perm997                5.0                1884.0                9.0
# Perm998                8.0                1936.0                6.0
# Perm999                6.0                1895.0                8.0
# True                  13.0                2707.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2145.0  0.634878                 1.115654
# Perm1                  2126.0  1.121308                 0.878938
# Perm2                  2093.0  0.180836                 0.291485
# Perm3                  2107.0  1.467015                 2.033362
# Perm4                  2195.0  0.901067                 1.163925
# ...                       ...       ...                      ...
# Perm996                2155.0  0.461703                 0.380744
# Perm997                2138.0  0.630455                 0.999363
# Perm998                2086.0  1.436639                 4.556904
# Perm999                2127.0  0.841821                 0.717991
# True                   1315.0  6.315109                 7.714313
#
# [1001 rows x 6 columns]
# Case interactome muts: 20
# Case non-interactome muts: 2881
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 1344
# Odds ratio: 9.330093717459215
# Synonymous OR:  0.8089471913891692
# Corrected OR:  11.533625206655405
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  9.0                2107.0               12.0
# Perm1                 10.0                2021.0               11.0
# Perm2                  7.0                1993.0               14.0
# Perm3                 10.0                2040.0               11.0
# Perm4                  9.0                1988.0               12.0
# ...                    ...                   ...                ...
# Perm996               11.0                2081.0               10.0
# Perm997                5.0                2061.0               16.0
# Perm998                9.0                2038.0               12.0
# Perm999                7.0                2072.0               14.0
# True                  20.0                2881.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2118.0  0.753916                 5.710350
# Perm1                  2204.0  0.991408                 0.446311
# Perm2                  2232.0  0.559960                 0.219787
# Perm3                  2185.0  0.973708                 0.767845
# Perm4                  2237.0  0.843939                 2.132556
# ...                       ...       ...                      ...
# Perm996                2144.0  1.133301                 2.027173
# Perm997                2164.0  0.328117                 0.483844
# Perm998                2187.0  0.804833                 1.951770
# Perm999                2153.0  0.519546                 1.780978
# True                   1344.0  9.330094                11.533625
#
# [1001 rows x 6 columns]
# Interactome:  GATA4-TBX5
# Case interactome muts: 54
# Case non-interactome muts: 2666
# Ctrl interactome muts: 16
# Ctrl non-interactome muts: 1300
# Odds ratio: 1.6457239309827456
# Synonymous OR:  0.575440266539743
# Corrected OR:  2.8599387750163343
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 32.0                1844.0               38.0
# Perm1                 37.0                1896.0               33.0
# Perm2                 36.0                1843.0               34.0
# Perm3                 34.0                1846.0               36.0
# Perm4                 34.0                1880.0               36.0
# ...                    ...                   ...                ...
# Perm996               31.0                1872.0               39.0
# Perm997               34.0                1891.0               36.0
# Perm998               35.0                1837.0               35.0
# Perm999               29.0                1859.0               41.0
# True                  54.0                2666.0               16.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2122.0  0.969060                 1.039450
# Perm1                  2070.0  1.224108                 0.917261
# Perm2                  2123.0  1.219687                 1.453411
# Perm3                  2120.0  1.084627                 1.235339
# Perm4                  2086.0  1.047931                 0.924659
# ...                       ...       ...                      ...
# Perm996                2094.0  0.889135                 0.892576
# Perm997                2075.0  1.036342                 1.344573
# Perm998                2129.0  1.158955                 1.025569
# Perm999                2107.0  0.801677                 0.905041
# True                   1300.0  1.645724                 2.859939
#
# [1001 rows x 6 columns]
# Case interactome muts: 89
# Case non-interactome muts: 2812
# Ctrl interactome muts: 16
# Ctrl non-interactome muts: 1329
# Odds ratio: 2.6289340327169275
# Synonymous OR:  0.6421768707482993
# Corrected OR:  4.093784987387588
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 52.0                1960.0               53.0
# Perm1                 56.0                2004.0               49.0
# Perm2                 50.0                2044.0               55.0
# Perm3                 57.0                2029.0               48.0
# Perm4                 51.0                2003.0               54.0
# ...                    ...                   ...                ...
# Perm996               50.0                2035.0               55.0
# Perm997               55.0                1952.0               50.0
# Perm998               61.0                2061.0               44.0
# Perm999               47.0                1992.0               58.0
# True                  89.0                2812.0               16.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2181.0  1.091760                 1.150543
# Perm1                  2137.0  1.218705                 1.092945
# Perm2                  2097.0  0.932663                 0.594795
# Perm3                  2112.0  1.236077                 1.218590
# Perm4                  2138.0  1.008099                 1.164260
# ...                       ...       ...                      ...
# Perm996                2106.0  0.940809                 0.996857
# Perm997                2189.0  1.233555                 1.784594
# Perm998                2080.0  1.399144                 1.069791
# Perm999                2149.0  0.874212                 1.546532
# True                   1329.0  2.628934                 4.093785
#
# [1001 rows x 6 columns]
# Interactome:  GATA4
# Case interactome muts: 34
# Case non-interactome muts: 2258
# Ctrl interactome muts: 12
# Ctrl non-interactome muts: 1159
# Odds ratio: 1.4543105993504577
# Synonymous OR:  0.4869655891553702
# Corrected OR:  2.9864750851757793
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 18.0                1509.0               28.0
# Perm1                 20.0                1531.0               26.0
# Perm2                 15.0                1521.0               31.0
# Perm3                 16.0                1506.0               30.0
# Perm4                 17.0                1483.0               29.0
# ...                    ...                   ...                ...
# Perm996               22.0                1502.0               24.0
# Perm997               29.0                1475.0               17.0
# Perm998               16.0                1519.0               30.0
# Perm999               23.0                1537.0               23.0
# True                  34.0                2258.0               12.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1908.0  0.812837                 0.878249
# Perm1                  1886.0  0.947596                 1.079700
# Perm2                  1896.0  0.603169                 0.570113
# Perm3                  1911.0  0.676760                 0.714389
# Perm4                  1934.0  0.764480                 0.601755
# ...                       ...       ...                      ...
# Perm996                1915.0  1.168719                 0.830952
# Perm997                1942.0  2.245982                 1.347478
# Perm998                1898.0  0.666403                 0.381159
# Perm999                1880.0  1.223162                 0.716954
# True                   1159.0  1.454311                 2.986475
#
# [1001 rows x 6 columns]
# Case interactome muts: 45
# Case non-interactome muts: 2366
# Ctrl interactome muts: 12
# Ctrl non-interactome muts: 1183
# Odds ratio: 1.875
# Synonymous OR:  0.5780487804878048
# Corrected OR:  3.2436708860759498
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 26.0                1645.0               31.0
# Perm1                 23.0                1611.0               34.0
# Perm2                 20.0                1622.0               37.0
# Perm3                 26.0                1634.0               31.0
# Perm4                 22.0                1684.0               35.0
# ...                    ...                   ...                ...
# Perm996               29.0                1613.0               28.0
# Perm997               22.0                1589.0               35.0
# Perm998               31.0                1575.0               26.0
# Perm999               25.0                1603.0               32.0
# True                  45.0                2366.0               12.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1904.0  0.970762                 0.603809
# Perm1                  1938.0  0.813780                 1.859376
# Perm2                  1927.0  0.642183                 0.440944
# Perm3                  1915.0  0.982943                 0.907731
# Perm4                  1865.0  0.696132                 0.725381
# ...                       ...       ...                      ...
# Perm996                1936.0  1.243114                 0.961933
# Perm997                1960.0  0.775330                 1.158547
# Perm998                1974.0  1.494359                 2.382496
# Perm999                1946.0  0.948417                 0.762653
# True                   1183.0  1.875000                 3.243671
#
# [1001 rows x 6 columns]
# Interactome:  TBX5
# Case interactome muts: 13
# Case non-interactome muts: 2279
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 1170
# Odds ratio: 6.673979815708644
# Synonymous OR:  0.8186223606784354
# Corrected OR:  8.152696696652123
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  4.0                1549.0               10.0
# Perm1                  6.0                1566.0                8.0
# Perm2                  8.0                1518.0                6.0
# Perm3                  7.0                1550.0                7.0
# Perm4                  2.0                1603.0               12.0
# ...                    ...                   ...                ...
# Perm996                4.0                1557.0               10.0
# Perm997                5.0                1493.0                9.0
# Perm998                6.0                1526.0                8.0
# Perm999                9.0                1527.0                5.0
# True                  13.0                2279.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1900.0  0.490639                 5.555741
# Perm1                  1883.0  0.901820                 0.618149
# Perm2                  1931.0  1.696091                 0.711756
# Perm3                  1899.0  1.225161                 1.232006
# Perm4                  1846.0  0.191932                 0.525193
# ...                       ...       ...                      ...
# Perm996                1892.0  0.486063                 0.738911
# Perm997                1956.0  0.727841                 1.286166
# Perm998                1923.0  0.945118                 0.501582
# Perm999                1922.0  2.265619                 4.319642
# True                   1170.0  6.673980                 8.152697
#
# [1001 rows x 6 columns]
# Case interactome muts: 16
# Case non-interactome muts: 2395
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 1194
# Odds ratio: 7.976617954070981
# Synonymous OR:  0.8089471913891692
# Corrected OR:  9.860492797277766
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  5.0                1667.0               12.0
# Perm1                  6.0                1643.0               11.0
# Perm2                  7.0                1661.0               10.0
# Perm3                 12.0                1661.0                5.0
# Perm4                 11.0                1620.0                6.0
# ...                    ...                   ...                ...
# Perm996                7.0                1615.0               10.0
# Perm997                5.0                1649.0               12.0
# Perm998               11.0                1646.0                6.0
# Perm999               11.0                1595.0                6.0
# True                  16.0                2395.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1922.0  0.480404                 0.117508
# Perm1                  1946.0  0.646047                 3.164584
# Perm2                  1928.0  0.812523                 1.207992
# Perm3                  1928.0  2.785792                 6.115632
# Perm4                  1969.0  2.228292                 0.736733
# ...                       ...       ...                      ...
# Perm996                1974.0  0.855604                 1.000677
# Perm997                1940.0  0.490196                 1.617437
# Perm998                1943.0  2.164135                 7.025022
# Perm999                1994.0  2.291954                 2.526496
# True                   1194.0  7.976618                 9.860493
#
# [1001 rows x 6 columns]
# Interactome:  GATA4-TBX5
# Case interactome muts: 44
# Case non-interactome muts: 2248
# Ctrl interactome muts: 13
# Ctrl non-interactome muts: 1158
# Odds ratio: 1.7434984943881742
# Synonymous OR:  0.575440266539743
# Corrected OR:  3.029851395127836
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 23.0                1518.0               34.0
# Perm1                 27.0                1512.0               30.0
# Perm2                 29.0                1538.0               28.0
# Perm3                 31.0                1537.0               26.0
# Perm4                 20.0                1477.0               37.0
# ...                    ...                   ...                ...
# Perm996               26.0                1536.0               31.0
# Perm997               25.0                1507.0               32.0
# Perm998               25.0                1528.0               32.0
# Perm999               28.0                1496.0               29.0
# True                  44.0                2248.0               13.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1888.0  0.841355                 1.473646
# Perm1                  1894.0  1.127381                 1.175025
# Perm2                  1868.0  1.257942                 1.650598
# Perm3                  1869.0  1.449852                 1.206237
# Perm4                  1929.0  0.705960                 0.603462
# ...                       ...       ...                      ...
# Perm996                1870.0  1.021085                 1.677583
# Perm997                1899.0  0.984468                 0.918837
# Perm998                1878.0  0.960201                 1.471353
# Perm999                1910.0  1.232713                 1.384800
# True                   1158.0  1.743498                 3.029851
#
# [1001 rows x 6 columns]
# Case interactome muts: 58
# Case non-interactome muts: 2353
# Ctrl interactome muts: 13
# Ctrl non-interactome muts: 1182
# Odds ratio: 2.241197816208441
# Synonymous OR:  0.6421768707482993
# Corrected OR:  3.490000836680517
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 32.0                1646.0               39.0
# Perm1                 28.0                1620.0               43.0
# Perm2                 39.0                1582.0               32.0
# Perm3                 33.0                1663.0               38.0
# Perm4                 35.0                1648.0               36.0
# ...                    ...                   ...                ...
# Perm996               28.0                1567.0               43.0
# Perm997               35.0                1624.0               36.0
# Perm998               33.0                1618.0               38.0
# Perm999               35.0                1631.0               36.0
# True                  58.0                2353.0               13.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1889.0  0.941646                 2.406573
# Perm1                  1915.0  0.769739                 0.840126
# Perm2                  1953.0  1.504563                 0.537293
# Perm3                  1872.0  0.977561                 0.958890
# Perm4                  1887.0  1.113218                 1.943978
# ...                       ...       ...                      ...
# Perm996                1968.0  0.817797                 1.375558
# Perm997                1911.0  1.144037                 1.500377
# Perm998                1917.0  1.028902                 0.981819
# Perm999                1904.0  1.134955                 1.016691
# True                   1182.0  2.241198                 3.490001
#
# [1001 rows x 6 columns]
# Interactome:  GATA4
# Case interactome muts: 8
# Case non-interactome muts: 384
# Ctrl interactome muts: 3
# Ctrl non-interactome muts: 120
# Odds ratio: 0.8333333333333334
# Synonymous OR:  0.4869655891553702
# Corrected OR:  1.7112776588151322
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  2.0                 137.0                9.0
# Perm1                  1.0                 128.0               10.0
# Perm2                  2.0                 122.0                9.0
# Perm3                  4.0                 122.0                7.0
# Perm4                  3.0                 125.0                8.0
# ...                    ...                   ...                ...
# Perm996                2.0                 133.0                9.0
# Perm997                3.0                 135.0                8.0
# Perm998                2.0                 112.0                9.0
# Perm999                4.0                 141.0                7.0
# True                   8.0                 384.0                3.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   367.0  0.595296                 0.703633
# Perm1                   376.0  0.293750                 0.403619
# Perm2                   382.0  0.695811                 1.662848
# Perm3                   382.0  1.789227                 1.133342
# Perm4                   379.0  1.137000                 1.109977
# ...                       ...       ...                      ...
# Perm996                 371.0  0.619883                 1.594806
# Perm997                 369.0  1.025000                 1.459009
# Perm998                 392.0  0.777778                 1.218782
# Perm999                 363.0  1.471125                 0.650032
# True                    120.0  0.833333                 1.711278
#
# [1001 rows x 6 columns]
# Case interactome muts: 23
# Case non-interactome muts: 423
# Ctrl interactome muts: 3
# Ctrl non-interactome muts: 124
# Odds ratio: 2.2474389282899923
# Synonymous OR:  0.5780487804878048
# Corrected OR:  3.8879745172949236
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  6.0                 149.0               20.0
# Perm1                  5.0                 139.0               21.0
# Perm2                  8.0                 152.0               18.0
# Perm3                 10.0                 143.0               16.0
# Perm4                  6.0                 141.0               20.0
# ...                    ...                   ...                ...
# Perm996                6.0                 145.0               20.0
# Perm997                9.0                 144.0               17.0
# Perm998                6.0                 151.0               20.0
# Perm999                8.0                 136.0               18.0
# True                  23.0                 423.0                3.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   398.0  0.801342                 0.361522
# Perm1                   408.0  0.698869                 0.914676
# Perm2                   395.0  1.154971                 1.181049
# Perm3                   404.0  1.765734                 1.326897
# Perm4                   406.0  0.863830                 1.251104
# ...                       ...       ...                      ...
# Perm996                 402.0  0.831724                 0.965167
# Perm997                 403.0  1.481618                 0.587240
# Perm998                 396.0  0.786755                 0.774604
# Perm999                 411.0  1.343137                 0.796406
# True                    124.0  2.247439                 3.887975
#
# [1001 rows x 6 columns]
# Interactome:  TBX5
# Case interactome muts: 0.5
# Case non-interactome muts: 392.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 123.5
# Odds ratio: 0.3146496815286624
# Synonymous OR:  0.8186223606784354
# Corrected OR:  0.3843648752373386
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                 141.5                0.5
# Perm1                  0.5                 131.5                0.5
# Perm2                  0.5                 127.5                0.5
# Perm3                  0.5                 122.5                0.5
# Perm4                  0.5                 133.5                0.5
# ...                    ...                   ...                ...
# Perm996                0.5                 127.5                0.5
# Perm997                0.5                 124.5                0.5
# Perm998                0.5                 115.5                0.5
# Perm999                0.5                 143.5                0.5
# True                   0.5                 392.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   374.5  2.646643                 8.455300
# Perm1                   384.5  2.923954                 6.873333
# Perm2                   388.5  3.047059                 2.879638
# Perm3                   393.5  3.212245                 2.989498
# Perm4                   382.5  2.865169                 0.851527
# ...                       ...       ...                      ...
# Perm996                 388.5  3.047059                 0.945255
# Perm997                 391.5  3.144578                 4.086069
# Perm998                 400.5  3.467532                 2.478452
# Perm999                 372.5  2.595819                 8.159410
# True                    123.5  0.314650                 0.384365
#
# [1001 rows x 6 columns]
# Case interactome muts: 3.5
# Case non-interactome muts: 443.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 127.5
# Odds ratio: 2.012401352874859
# Synonymous OR:  0.8089471913891692
# Corrected OR:  2.4876795102274247
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                 141.5                3.5
# Perm1                  1.0                 151.0                2.0
# Perm2                  1.0                 159.0                2.0
# Perm3                  0.5                 149.5                3.5
# Perm4                  2.0                 176.0                1.0
# ...                    ...                   ...                ...
# Perm996                1.0                 141.0                2.0
# Perm997                1.0                 155.0                2.0
# Perm998                1.0                 147.0                2.0
# Perm999                3.5                 143.5                0.5
# True                   3.5                 443.5                0.5
#
#          ctrl_nonintact_count         OR  synonymous-corrected OR
# Perm0                   429.5   0.433619                 0.211768
# Perm1                   419.0   1.387417                 1.146964
# Perm2                   411.0   1.292453                 1.301835
# Perm3                   421.5   0.402771                 0.188925
# Perm4                   394.0   4.477273                15.306025
# ...                       ...        ...                      ...
# Perm996                 429.0   1.521277                 0.796859
# Perm997                 415.0   1.338710                 0.709105
# Perm998                 423.0   1.438776                 3.106476
# Perm999                 427.5  20.853659                 6.875868
# True                    127.5   2.012401                 2.487680
#
# [1001 rows x 6 columns]
# Interactome:  GATA4-TBX5
# Case interactome muts: 8
# Case non-interactome muts: 384
# Ctrl interactome muts: 3
# Ctrl non-interactome muts: 120
# Odds ratio: 0.8333333333333334
# Synonymous OR:  0.575440266539743
# Corrected OR:  1.44816652881169
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                 116.5               11.5
# Perm1                  2.0                 127.0                9.0
# Perm2                  4.0                 110.0                7.0
# Perm3                  4.0                 122.0                7.0
# Perm4                  0.5                 116.5               11.5
# ...                    ...                   ...                ...
# Perm996                3.0                 147.0                8.0
# Perm997                2.0                 120.0                9.0
# Perm998                3.0                 132.0                8.0
# Perm999                3.0                 136.0                8.0
# True                   8.0                 384.0                3.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   388.5  0.144990                 0.101810
# Perm1                   377.0  0.659668                 0.263788
# Perm2                   394.0  2.046753                 4.201623
# Perm3                   382.0  1.789227                 1.644377
# Perm4                   388.5  0.144990                 0.104927
# ...                       ...       ...                      ...
# Perm996                 357.0  0.910714                 0.391616
# Perm997                 384.0  0.711111                 0.757792
# Perm998                 372.0  1.056818                 1.650668
# Perm999                 368.0  1.014706                 0.969482
# True                    120.0  0.833333                 1.448167
#
# [1001 rows x 6 columns]
# Case interactome muts: 26
# Case non-interactome muts: 420
# Ctrl interactome muts: 3
# Ctrl non-interactome muts: 124
# Odds ratio: 2.5587301587301585
# Synonymous OR:  0.6421768707482993
# Corrected OR:  3.984463276836158
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  8.0                 164.0               21.0
# Perm1                  8.0                 152.0               21.0
# Perm2                 10.0                 143.0               19.0
# Perm3                  9.0                 140.0               20.0
# Perm4                  6.0                 155.0               23.0
# ...                    ...                   ...                ...
# Perm996                9.0                 134.0               20.0
# Perm997                8.0                 143.0               21.0
# Perm998                5.0                 149.0               24.0
# Perm999                4.0                 143.0               25.0
# True                  26.0                 420.0                3.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   380.0  0.882695                 1.056177
# Perm1                   392.0  0.982456                 1.858124
# Perm2                   401.0  1.475893                 1.027669
# Perm3                   404.0  1.298571                 1.411423
# Perm4                   389.0  0.654698                 0.736806
# ...                       ...       ...                      ...
# Perm996                 410.0  1.376866                 1.028078
# Perm997                 401.0  1.068265                 1.754351
# Perm998                 395.0  0.552293                 0.327529
# Perm999                 401.0  0.448671                 0.243129
# True                    124.0  2.558730                 3.984463
#
# [1001 rows x 6 columns]
# Interactome:  GATA4
# Case interactome muts: 2.5
# Case non-interactome muts: 34.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 20.5
# Odds ratio: 2.971014492753623
# Synonymous OR:  0.4869655891553702
# Corrected OR:  6.1010768705582965
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                  13.5                2.5
# Perm1                  0.5                  10.5                2.5
# Perm2                  1.0                  14.0                1.0
# Perm3                  0.5                  12.5                2.5
# Perm4                  0.5                   7.5                2.5
# ...                    ...                   ...                ...
# Perm996                0.5                   6.5                2.5
# Perm997                0.5                  12.5                2.5
# Perm998                1.0                   8.0                1.0
# Perm999                0.5                  10.5                2.5
# True                   2.5                  34.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                    41.5  0.614815                 0.666224
# Perm1                    44.5  0.847619                 0.774989
# Perm2                    40.0  2.857143                 1.904594
# Perm3                    42.5  0.680000                 0.474399
# Perm4                    47.5  1.266667                 1.078378
# ...                       ...       ...                      ...
# Perm996                  48.5  1.492308                 2.637092
# Perm997                  42.5  0.680000                 0.242774
# Perm998                  46.0  5.750000                 4.899814
# Perm999                  44.5  0.847619                 1.523129
# True                     20.5  2.971014                 6.101077
#
# [1001 rows x 6 columns]
# Case interactome muts: 4.5
# Case non-interactome muts: 40.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 21.5
# Odds ratio: 4.777777777777778
# Synonymous OR:  0.5780487804878048
# Corrected OR:  8.265353961556494
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                  15.5                4.5
# ...
#
# [1001 rows x 6 columns]
# Case interactome muts: 28
# Case non-interactome muts: 470
# Ctrl interactome muts: 3
# Ctrl non-interactome muts: 124
# Odds ratio: 2.4624113475177305
# Synonymous OR:  0.6483516483516484
# Corrected OR:  3.7979564851544656
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 11.0                 179.0               20.0
# Perm1                  7.0                 182.0               24.0
# Perm2                 12.0                 162.0               19.0
# Perm3                  7.0                 165.0               24.0
# Perm4                  8.0                 187.0               23.0
# ...                    ...                   ...                ...
# Perm996                9.0                 174.0               22.0
# Perm997               12.0                 173.0               19.0
# Perm998               10.0                 191.0               21.0
# Perm999               11.0                 171.0               20.0
# True                  28.0                 470.0                3.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   415.0  1.275140                 1.120985
# Perm1                   412.0  0.660256                 0.650176
# Perm2                   432.0  1.684211                 2.587424
# Perm3                   429.0  0.758333                 0.987768
# Perm4                   407.0  0.757033                 0.754396
# ...                       ...       ...                      ...
# Perm996                 420.0  0.987461                 0.687818
# Perm997                 421.0  1.536964                 1.958173
# Perm998                 403.0  1.004737                 1.188003
# Perm999                 423.0  1.360526                 1.235756
# True                    124.0  2.462411                 3.797956
#
# [1001 rows x 6 columns]
# Interactome:  GATA4
# Case interactome muts: 2.5
# Case non-interactome muts: 65.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 20.5
# Odds ratio: 1.5648854961832062
# Synonymous OR:  0.4863063625950224
# Corrected OR:  3.2179005181685927
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  1.0                  13.0                1.0
# Perm1                  0.5                  18.5                2.5
# Perm2                  1.0                  23.0                1.0
# Perm3                  0.5                  26.5                2.5
# Perm4                  0.5                  22.5                2.5
# ...                    ...                   ...                ...
# Perm996                0.5                  20.5                2.5
# Perm997                0.5                  20.5                2.5
# Perm998                1.0                  15.0                1.0
# Perm999                0.5                  15.5                2.5
# True                   2.5                  65.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                    72.0  5.538462                 3.770103
# Perm1                    67.5  0.729730                 3.712103
# Perm2                    62.0  2.695652                13.247844
# Perm3                    59.5  0.449057                 0.278104
# Perm4                    63.5  0.564444                 1.199209
# ...                       ...       ...                      ...
# Perm996                  65.5  0.639024                 0.345011
# Perm997                  65.5  0.639024                 0.934122
# Perm998                  70.0  4.666667                 2.483122
# Perm999                  70.5  0.909677                 1.752091
# True                     20.5  1.564885                 3.217901
#
# [1001 rows x 6 columns]
# Case interactome muts: 5.5
# Case non-interactome muts: 73.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 21.5
# Odds ratio: 3.2176870748299318
# Synonymous OR:  0.5617137648131267
# Corrected OR:  5.728339372100673
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  1.0                  16.0                4.0
# Perm1                  0.5                  17.5                5.5
# Perm2                  3.0                  25.0                2.0
# Perm3                  0.5                  24.5                5.5
# Perm4                  1.0                  18.0                4.0
# ...                    ...                   ...                ...
# Perm996                4.0                  30.0                1.0
# Perm997                1.0                  19.0                4.0
# Perm998                1.0                  20.0                4.0
# Perm999                1.0                  17.0                4.0
# True                   5.5                  73.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                    78.0  1.218750                 0.545424
# Perm1                    77.5  0.402597                 0.192847
# Perm2                    69.0  4.140000                 2.074016
# Perm3                    70.5  0.261596                 0.114510
# Perm4                    76.0  1.055556                 0.844732
# ...                       ...       ...                      ...
# Perm996                  64.0  8.533333                24.100808
# Perm997                  75.0  0.986842                 1.007159
# Perm998                  74.0  0.925000                 0.652083
# Perm999                  77.0  1.132353                 1.181440
# True                     21.5  3.217687                 5.728339
#
# [1001 rows x 6 columns]
# Interactome:  TBX5
# Case interactome muts: 0.5
# Case non-interactome muts: 67.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 20.5
# Odds ratio: 0.3037037037037037
# Synonymous OR:  0.8832866479925303
# Corrected OR:  0.3438336856941508
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                  19.5                0.5
# Perm1                  0.5                  22.5                0.5
# Perm2                  0.5                  12.5                0.5
# Perm3                  0.5                  17.5                0.5
# Perm4                  0.5                  23.5                0.5
# ...                    ...                   ...                ...
# Perm996                0.5                  27.5                0.5
# Perm997                0.5                  18.5                0.5
# Perm998                0.5                  24.5                0.5
# Perm999                0.5                  19.5                0.5
# True                   0.5                  67.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                    68.5  3.512821                 8.086226
# Perm1                    65.5  2.911111                 2.705902
# Perm2                    75.5  6.040000                 5.724329
# Perm3                    70.5  4.028571                 8.862192
# Perm4                    64.5  2.744681                 2.671974
# ...                       ...       ...                      ...
# Perm996                  60.5  2.200000                11.287546
# Perm997                  69.5  3.756757                 3.699080
# Perm998                  63.5  2.591837                 1.349871
# Perm999                  68.5  3.512821                 3.342099
# True                     20.5  0.303704                 0.343834
#
# [1001 rows x 6 columns]
# Case interactome muts: 2.5
# Case non-interactome muts: 76.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 21.5
# Odds ratio: 1.4052287581699345
# Synonymous OR:  0.8713768115942029
# Corrected OR:  1.6126533773592595
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  1.0                  23.0                1.0
# Perm1                  1.0                  18.0                1.0
# Perm2                  0.5                  22.5                2.5
# Perm3                  0.5                  15.5                2.5
# Perm4                  0.5                  25.5                2.5
# ...                    ...                   ...                ...
# Perm996                1.0                  22.0                1.0
# Perm997                1.0                  16.0                1.0
# Perm998                0.5                  24.5                2.5
# Perm999                1.0                  24.0                1.0
# True                   2.5                  76.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                    74.0  3.217391                 1.036399
# Perm1                    79.0  4.388889                10.318367
# Perm2                    75.5  0.671111                 1.011209
# Perm3                    82.5  1.064516                 0.542421
# Perm4                    72.5  0.568627                 2.909580
# ...                       ...       ...                      ...
# Perm996                  75.0  3.409091                 1.172475
# Perm997                  81.0  5.062500                 5.151135
# Perm998                  73.5  0.600000                 0.478729
# Perm999                  73.0  3.041667                 3.912964
# True                     21.5  1.405229                 1.612653
#
# [1001 rows x 6 columns]
# Interactome:  GATA4-TBX5
# Case interactome muts: 2.5
# Case non-interactome muts: 65.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 20.5
# Odds ratio: 1.5648854961832062
# Synonymous OR:  0.5970724191063174
# Corrected OR:  2.6209308052203895
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  1.0                  13.0                1.0
# Perm1                  0.5                  25.5                2.5
# Perm2                  0.5                  19.5                2.5
# Perm3                  0.5                  18.5                2.5
# Perm4                  0.5                  24.5                2.5
# ...                    ...                   ...                ...
# Perm996                0.5                  26.5                2.5
# Perm997                0.5                  21.5                2.5
# Perm998                0.5                  21.5                2.5
# Perm999                0.5                  12.5                2.5
# True                   2.5                  65.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                    72.0  5.538462                 8.593683
# Perm1                    60.5  0.474510                 0.418486
# Perm2                    66.5  0.682051                 4.755508
# Perm3                    67.5  0.729730                 0.901790
# Perm4                    61.5  0.502041                 0.376543
# ...                       ...       ...                      ...
# Perm996                  59.5  0.449057                 0.398417
# Perm997                  64.5  0.600000                 0.686700
# Perm998                  64.5  0.600000                 0.678320
# Perm999                  73.5  1.176000                 1.018812
# True                     20.5  1.564885                 2.620931
#
# [1001 rows x 6 columns]
# Case interactome muts: 7.5
# Case non-interactome muts: 71.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 21.5
# Odds ratio: 4.510489510489511
# Synonymous OR:  0.6483516483516484
# Corrected OR:  6.956856702619414
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  3.0                  21.0                4.0
# Perm1                  1.0                  25.0                6.0
# Perm2                  1.0                  18.0                6.0
# Perm3                  2.0                  21.0                5.0
# Perm4                  0.5                  22.5                7.5
# ...                    ...                   ...                ...
# Perm996                0.5                  22.5                7.5
# Perm997                1.0                  24.0                6.0
# Perm998                2.0                  25.0                5.0
# Perm999                1.0                  22.0                6.0
# True                   7.5                  71.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                    71.0  2.535714                 3.668737
# Perm1                    67.0  0.446667                 0.418458
# Perm2                    74.0  0.685185                 0.840046
# Perm3                    71.0  1.352381                 0.990742
# Perm4                    70.5  0.208889                 0.195697
# ...                       ...       ...                      ...
# Perm996                  70.5  0.208889                 0.414814
# Perm997                  68.0  0.472222                 0.386286
# Perm998                  67.0  1.072000                 1.870566
# Perm999                  70.0  0.530303                 1.227711
# True                     21.5  4.510490                 6.956857
#
# [1001 rows x 6 columns]
#    Interactome           Cell Type   Variant Type Included Genes  \
# 0        GATA4  cardiac progenitor  lof-inherited   unknownGenes
# 1        GATA4  cardiac progenitor  lof-inherited   unknownGenes
# 2        GATA4  cardiac progenitor  lof-inherited       allGenes
# 3        GATA4  cardiac progenitor  lof-inherited       allGenes
# 4         TBX5  cardiac progenitor  lof-inherited   unknownGenes
# ..         ...                 ...            ...            ...
# 67        TBX5  cardiac progenitor     splice-dnv       allGenes
# 68  GATA4-TBX5  cardiac progenitor     splice-dnv   unknownGenes
# 69  GATA4-TBX5  cardiac progenitor     splice-dnv   unknownGenes
# 70  GATA4-TBX5  cardiac progenitor     splice-dnv       allGenes
# 71  GATA4-TBX5  cardiac progenitor     splice-dnv       allGenes
#
#        Correction  case_intact_count  case_nonintact_count  ctrl_intact_count  \
# 0        original               59.0                9636.0               48.0
# 1   syn-corrected               59.0                9636.0               48.0
# 2        original               64.0                9819.0               52.0
# 3   syn-corrected               64.0                9819.0               52.0
# 4        original               20.0                9675.0               21.0
# ..            ...                ...                   ...                ...
# 67  syn-corrected                2.5                  76.5                0.5
# 68       original                2.5                  65.5                0.5
# 69  syn-corrected                2.5                  65.5                0.5
# 70       original                7.5                  71.5                0.5
# 71  syn-corrected                7.5                  71.5                0.5
#
#     ctrl_nonintact_count        OR  synonymous-corrected OR
# 0                10314.0  1.315652                 1.315652
# 1                10314.0  1.315652                 1.315652
# 2                10469.0  1.312244                 1.312244
# 3                10469.0  1.312244                 1.312244
# 4                10341.0  1.017940                 1.017940
# ..                   ...       ...                      ...
# 67                  21.5  1.405229                 1.612653
# 68                  20.5  1.564885                 2.620931
# 69                  20.5  1.564885                 2.620931
# 70                  21.5  4.510490                 6.956857
# 71                  21.5  4.510490                 6.956857
#
# [72 rows x 11 columns]

# %%
data_df
# Out:
#    Interactome           Cell Type   Variant Type Included Genes  \
# 0        GATA4  cardiac progenitor  lof-inherited   unknownGenes
# 1        GATA4  cardiac progenitor  lof-inherited   unknownGenes
# 2        GATA4  cardiac progenitor  lof-inherited       allGenes
# 3        GATA4  cardiac progenitor  lof-inherited       allGenes
# 4         TBX5  cardiac progenitor  lof-inherited   unknownGenes
# ..         ...                 ...            ...            ...
# 67        TBX5  cardiac progenitor     splice-dnv       allGenes
# 68  GATA4-TBX5  cardiac progenitor     splice-dnv   unknownGenes
# 69  GATA4-TBX5  cardiac progenitor     splice-dnv   unknownGenes
# 70  GATA4-TBX5  cardiac progenitor     splice-dnv       allGenes
# 71  GATA4-TBX5  cardiac progenitor     splice-dnv       allGenes
#
#        Correction  case_intact_count  case_nonintact_count  ctrl_intact_count  \
# 0        original               59.0                9636.0               48.0
# 1   syn-corrected               59.0                9636.0               48.0
# 2        original               64.0                9819.0               52.0
# 3   syn-corrected               64.0                9819.0               52.0
# 4        original               20.0                9675.0               21.0
# ..            ...                ...                   ...                ...
# 67  syn-corrected                2.5                  76.5                0.5
# 68       original                2.5                  65.5                0.5
# 69  syn-corrected                2.5                  65.5                0.5
# 70       original                7.5                  71.5                0.5
# 71  syn-corrected                7.5                  71.5                0.5
#
#     ctrl_nonintact_count        OR  synonymous-corrected OR
# 0                10314.0  1.315652                 1.315652
# 1                10314.0  1.315652                 1.315652
# 2                10469.0  1.312244                 1.312244
# 3                10469.0  1.312244                 1.312244
# 4                10341.0  1.017940                 1.017940
# ..                   ...       ...                      ...
# 67                  21.5  1.405229                 1.612653
# 68                  20.5  1.564885                 2.620931
# 69                  20.5  1.564885                 2.620931
# 70                  21.5  4.510490                 6.956857
# 71                  21.5  4.510490                 6.956857
#
# [72 rows x 11 columns]

# %% [markdown]
# ### Repeat above step for HEK interactomes

# %%
# Get results for rare inherited loss-of-function variants
case_filename = '../data/variants/LoF_cases.csv'
ctrl_filename = '../data/variants/LoF_ctrls.csv' 
cell_type = 'HEK'
variant_str = ['exonic','splice']
mut_type = 'lof-inherited'

results_dict = permutation_routine("HEK-GATA4", case_filename, ctrl_filename, variant_str, mut_type, cell_type)
results_dict.update(permutation_routine("HEK-TBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
results_dict.update(permutation_routine("HEKGATA4-HEKTBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
# Out:
# Interactome:  HEK-GATA4
# Case interactome muts: 25
# Case non-interactome muts: 9670
# Ctrl interactome muts: 25
# Ctrl non-interactome muts: 10337
# Odds ratio: 1.068976215098242
# Synonymous OR:  1.0
# Corrected OR:  1.068976215098242
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 23.0                7947.0               27.0
# Perm1                 13.0                7982.0               37.0
# Perm2                 24.0                7908.0               26.0
# Perm3                 21.0                7952.0               29.0
# Perm4                 18.0                7915.0               32.0
# ...                    ...                   ...                ...
# Perm996               17.0                7995.0               33.0
# Perm997               17.0                7897.0               33.0
# Perm998               18.0                7817.0               32.0
# Perm999               14.0                7831.0               36.0
# True                  25.0                9670.0               25.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 12060.0  1.292731                 1.292731
# Perm1                 12025.0  0.529316                 0.529316
# Perm2                 12099.0  1.412280                 1.412280
# Perm3                 12055.0  1.097772                 1.097772
# Perm4                 12092.0  0.859349                 0.859349
# ...                       ...       ...                      ...
# Perm996               12012.0  0.773984                 0.773984
# Perm997               12110.0  0.789982                 0.789982
# Perm998               12190.0  0.877175                 0.877175
# Perm999               12176.0  0.604662                 0.604662
# True                  10337.0  1.068976                 1.068976
#
# [1001 rows x 6 columns]
# Case interactome muts: 27
# Case non-interactome muts: 9856
# Ctrl interactome muts: 28
# Ctrl non-interactome muts: 10493
# Odds ratio: 1.0266081574675325
# Synonymous OR:  1.0
# Corrected OR:  1.0266081574675325
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 25.0                8189.0               30.0
# Perm1                 29.0                8057.0               26.0
# Perm2                 22.0                8045.0               33.0
# Perm3                 25.0                8267.0               30.0
# Perm4                 24.0                8185.0               31.0
# ...                    ...                   ...                ...
# Perm996               23.0                8094.0               32.0
# Perm997               19.0                8183.0               36.0
# Perm998               25.0                8069.0               30.0
# Perm999               24.0                8035.0               31.0
# True                  27.0                9856.0               28.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 12160.0  1.237432                 1.237432
# Perm1                 12292.0  1.701664                 1.701664
# Perm2                 12304.0  1.019598                 1.019598
# Perm3                 12082.0  1.217894                 1.217894
# Perm4                 12164.0  1.150555                 1.150555
# ...                       ...       ...                      ...
# Perm996               12255.0  1.088248                 1.088248
# Perm997               12166.0  0.784669                 0.784669
# Perm998               12280.0  1.268228                 1.268228
# Perm999               12314.0  1.186487                 1.186487
# True                  10493.0  1.026608                 1.026608
#
# [1001 rows x 6 columns]
# Interactome:  HEK-TBX5
# Case interactome muts: 18
# Case non-interactome muts: 9677
# Ctrl interactome muts: 21
# Ctrl non-interactome muts: 10341
# Odds ratio: 0.9159568343199634
# Synonymous OR:  1.0
# Corrected OR:  0.9159568343199634
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 10.0                7993.0               29.0
# Perm1                 18.0                8002.0               21.0
# Perm2                 18.0                7850.0               21.0
# Perm3                 15.0                7931.0               24.0
# Perm4                 13.0                7909.0               26.0
# ...                    ...                   ...                ...
# Perm996               11.0                8070.0               28.0
# Perm997               11.0                7833.0               28.0
# Perm998               19.0                8044.0               20.0
# Perm999               17.0                8107.0               22.0
# True                  18.0                9677.0               21.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 12025.0  0.518773                 0.518773
# Perm1                 12016.0  1.287107                 1.287107
# Perm2                 12168.0  1.328626                 1.328626
# Perm3                 12087.0  0.952512                 0.952512
# Perm4                 12109.0  0.765520                 0.765520
# ...                       ...       ...                      ...
# Perm996               11948.0  0.581643                 0.581643
# Perm997               12185.0  0.611128                 0.611128
# Perm998               11974.0  1.414135                 1.414135
# Perm999               11911.0  1.135310                 1.135310
# True                  10341.0  0.915957                 0.915957
#
# [1001 rows x 6 columns]
# Case interactome muts: 18
# Case non-interactome muts: 9865
# Ctrl interactome muts: 21
# Ctrl non-interactome muts: 10500
# Odds ratio: 0.9123162696401419
# Synonymous OR:  1.0
# Corrected OR:  0.9123162696401419
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 11.0                8172.0               28.0
# Perm1                 14.0                8187.0               25.0
# Perm2                 22.0                8240.0               17.0
# Perm3                 15.0                8128.0               24.0
# Perm4                 16.0                8181.0               23.0
# ...                    ...                   ...                ...
# Perm996               17.0                8094.0               22.0
# Perm997               16.0                8141.0               23.0
# Perm998               13.0                8044.0               26.0
# Perm999               15.0                8022.0               24.0
# True                  18.0                9865.0               21.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 12193.0  0.586161                 0.586161
# Perm1                 12178.0  0.832989                 0.832989
# Perm2                 12125.0  1.904269                 1.904269
# Perm3                 12237.0  0.940960                 0.940960
# Perm4                 12184.0  1.036038                 1.036038
# ...                       ...       ...                      ...
# Perm996               12271.0  1.171502                 1.171502
# Perm997               12224.0  1.044546                 1.044546
# Perm998               12321.0  0.765850                 0.765850
# Perm999               12343.0  0.961652                 0.961652
# True                  10500.0  0.912316                 0.912316
#
# [1001 rows x 6 columns]
# Interactome:  HEKGATA4-HEKTBX5
# Case interactome muts: 42
# Case non-interactome muts: 9653
# Ctrl interactome muts: 46
# Ctrl non-interactome muts: 10316
# Odds ratio: 0.9757543273323455
# Synonymous OR:  1.0
# Corrected OR:  0.9757543273323455
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 34.0                8010.0               54.0
# Perm1                 39.0                7775.0               49.0
# Perm2                 31.0                7918.0               57.0
# Perm3                 33.0                8020.0               55.0
# Perm4                 35.0                7930.0               53.0
# ...                    ...                   ...                ...
# Perm996               37.0                7846.0               51.0
# Perm997               39.0                7796.0               49.0
# Perm998               32.0                7956.0               56.0
# Perm999               38.0                8017.0               50.0
# True                  42.0                9653.0               46.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 11959.0  0.940043                 0.940043
# Perm1                 12194.0  1.248287                 1.248287
# Perm2                 12051.0  0.827741                 0.827741
# Perm3                 11949.0  0.893940                 0.893940
# Perm4                 12039.0  1.002558                 1.002558
# ...                       ...       ...                      ...
# Perm996               12123.0  1.120968                 1.120968
# Perm997               12173.0  1.242780                 1.242780
# Perm998               12013.0  0.862817                 0.862817
# Perm999               11952.0  1.133032                 1.133032
# True                  10316.0  0.975754                 0.975754
#
# [1001 rows x 6 columns]
# Case interactome muts: 44
# Case non-interactome muts: 9839
# Ctrl interactome muts: 49
# Ctrl non-interactome muts: 10472
# Odds ratio: 0.9557301119451744
# Synonymous OR:  1.0
# Corrected OR:  0.9557301119451744
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 36.0                7969.0               57.0
# Perm1                 37.0                8045.0               56.0
# Perm2                 36.0                8173.0               57.0
# Perm3                 45.0                8159.0               48.0
# Perm4                 37.0                8081.0               56.0
# ...                    ...                   ...                ...
# Perm996               34.0                8195.0               59.0
# Perm997               43.0                8107.0               50.0
# Perm998               43.0                8189.0               50.0
# Perm999               37.0                8106.0               56.0
# True                  44.0                9839.0               49.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                 12342.0  0.978159                 0.978159
# Perm1                 12266.0  1.007374                 1.007374
# Perm2                 12138.0  0.937979                 0.937979
# Perm3                 12152.0  1.396311                 1.396311
# Perm4                 12230.0  0.999943                 0.999943
# ...                       ...       ...                      ...
# Perm996               12116.0  0.851995                 0.851995
# Perm997               12204.0  1.294615                 1.294615
# Perm998               12122.0  1.273039                 1.273039
# Perm999               12205.0  0.994821                 0.994821
# True                  10472.0  0.955730                 0.955730
#
# [1001 rows x 6 columns]

# %%
nb_path = '/pollard/home/mpittman/lab_notebooks' 
for dnv_subset in ['inner_join_dnvs','outer_join_dnvs','outer_nonFSfilt_dnvs']:
    case_filename = '{}/{}.csv'.format(nb_path, dnv_subset)
    ctrl_filename = '../data/variants/DNV_ctrls.csv' 
    cell_type = 'HEK'


    # Check that synonymous variants behave as expected
    variant_str = ['syn','synonymous']
    mut_type = 'synonymous-dnv'

    res_dict = results_dict.copy()
    res_dict.update(permutation_routine("HEK-GATA4", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
    res_dict.update(permutation_routine("HEK-TBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
    res_dict.update(permutation_routine("HEKGATA4-HEKTBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))


    # Get results for non-synonymous variants
    mut_dict = {'nonsynonymous-dnv':['non','frameshift','startloss','stoploss','misD',
                                     'splice','mis', 'loss', 'loss of function', 'non-frameshift'],
               'missense-dnv':['mis','misD'],
               'LoF-dnv':['non','frameshift','startloss','loss','loss of function'],
               'splice-dnv':['splice']}
    
    for mut_type in mut_dict:
        variant_str = mut_dict[mut_type]

        res_dict.update(permutation_routine("HEK-GATA4", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
        res_dict.update(permutation_routine("HEK-TBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))
        res_dict.update(permutation_routine("HEKGATA4-HEKTBX5", case_filename, ctrl_filename, variant_str, mut_type, cell_type))


    line_list = []
    for key in res_dict:
        interactome_name, cell_type, mut_type, known_str, correction = key.split('_')
        OR = res_dict[key]['OR']
        #pval = res_dict[key]['PVAL']
        count_array = res_dict[key]['true_counts']
        line_list.append([interactome_name, cell_type, mut_type, known_str, correction, count_array[0],
                          count_array[1], count_array[2], count_array[3], count_array[4], count_array[5]])
        #, pval])

    data_df = pd.DataFrame(line_list, columns = ['Interactome','Cell Type','Variant Type', 
                                                 'Included Genes', 'Correction', 
                                                 'case_intact_count', 'case_nonintact_count',
                                                 'ctrl_intact_count', 'ctrl_nonintact_count',
                                                 'OR', 'synonymous-corrected OR'])#, 'P-value'])
    print(data_df)
    data_df.to_csv('/pollard/home/mpittman/lab_notebooks/permutation_tests/permres_{}_{}.csv'.format(cell_type, dnv_subset))
# Out:
# Interactome:  HEK-GATA4
# Case interactome muts: 6
# Case non-interactome muts: 962
# Ctrl interactome muts: 4
# Ctrl non-interactome muts: 472
# Odds ratio: 0.735966735966736
# Synonymous OR:  0.735966735966736
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                 244.5               10.5
# Perm1                  2.0                 269.0                8.0
# Perm2                  2.0                 346.0                8.0
# Perm3                  2.0                 242.0                8.0
# Perm4                  4.0                 257.0                6.0
# ...                    ...                   ...                ...
# Perm996                2.0                 259.0                8.0
# Perm997                1.0                 278.0                9.0
# Perm998                5.0                 254.0                5.0
# Perm999                0.5                 271.5               10.5
# True                   6.0                 962.0                4.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1190.5  0.231863                      1.0
# Perm1                  1165.0  1.082714                      1.0
# Perm2                  1088.0  0.786127                      1.0
# Perm3                  1192.0  1.231405                      1.0
# Perm4                  1177.0  3.053178                      1.0
# ...                       ...       ...                      ...
# Perm996                1175.0  1.134170                      1.0
# Perm997                1156.0  0.462030                      1.0
# Perm998                1180.0  4.645669                      1.0
# Perm999                1163.5  0.204069                      1.0
# True                    472.0  0.735967                      1.0
#
# [1001 rows x 6 columns]
# Case interactome muts: 6
# Case non-interactome muts: 990
# Ctrl interactome muts: 4
# Ctrl non-interactome muts: 480
# Odds ratio: 0.7272727272727273
# Synonymous OR:  0.7272727272727273
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  4.0                 368.0                6.0
# Perm1                  1.0                 288.0                9.0
# Perm2                  3.0                 289.0                7.0
# Perm3                  4.0                 260.0                6.0
# Perm4                  2.0                 253.0                8.0
# ...                    ...                   ...                ...
# Perm996                1.0                 264.0                9.0
# Perm997                1.0                 261.0                9.0
# Perm998                0.5                 282.5               10.5
# Perm999                1.0                 242.0                9.0
# True                   6.0                 990.0                4.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1102.0  1.996377                      1.0
# Perm1                  1182.0  0.456019                      1.0
# Perm2                  1181.0  1.751359                      1.0
# Perm3                  1210.0  3.102564                      1.0
# Perm4                  1217.0  1.202569                      1.0
# ...                       ...       ...                      ...
# Perm996                1206.0  0.507576                      1.0
# Perm997                1209.0  0.514687                      1.0
# Perm998                1188.5  0.200337                      1.0
# Perm999                1228.0  0.563820                      1.0
# True                    480.0  0.727273                      1.0
#
# [1001 rows x 6 columns]
# Interactome:  HEK-TBX5
# Case interactome muts: 5
# Case non-interactome muts: 963
# Ctrl interactome muts: 3
# Ctrl non-interactome muts: 473
# Odds ratio: 0.8186223606784354
# Synonymous OR:  0.8186223606784354
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  4.0                 357.0                4.0
# Perm1                  2.0                 277.0                6.0
# Perm2                  1.0                 257.0                7.0
# Perm3                  2.0                 258.0                6.0
# Perm4                  3.0                 351.0                5.0
# ...                    ...                   ...                ...
# Perm996                1.0                 268.0                7.0
# Perm997                0.5                 351.5                8.5
# Perm998                2.0                 364.0                6.0
# Perm999                2.0                 245.0                6.0
# True                   5.0                 963.0                3.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1079.0  3.022409                      1.0
# Perm1                  1159.0  1.394705                      1.0
# Perm2                  1179.0  0.655364                      1.0
# Perm3                  1178.0  1.521964                      1.0
# Perm4                  1085.0  1.854701                      1.0
# ...                       ...       ...                      ...
# Perm996                1168.0  0.622601                      1.0
# Perm997                1085.5  0.181658                      1.0
# Perm998                1072.0  0.981685                      1.0
# Perm999                1191.0  1.620408                      1.0
# True                    473.0  0.818622                      1.0
#
# [1001 rows x 6 columns]
# Case interactome muts: 5
# Case non-interactome muts: 991
# Ctrl interactome muts: 3
# Ctrl non-interactome muts: 481
# Odds ratio: 0.8089471913891692
# Synonymous OR:  0.8089471913891692
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  1.0                 269.0                7.0
# Perm1                  1.0                 220.0                7.0
# Perm2                  3.0                 240.0                5.0
# Perm3                  2.0                 260.0                6.0
# Perm4                  2.0                 259.0                6.0
# ...                    ...                   ...                ...
# Perm996                3.0                 274.0                5.0
# Perm997                0.5                 271.5                8.5
# Perm998                1.0                 268.0                7.0
# Perm999                0.5                 263.5                8.5
# True                   5.0                 991.0                3.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1203.0  0.638874                      1.0
# Perm1                  1252.0  0.812987                      1.0
# Perm2                  1232.0  3.080000                      1.0
# Perm3                  1212.0  1.553846                      1.0
# Perm4                  1213.0  1.561133                      1.0
# ...                       ...       ...                      ...
# Perm996                1198.0  2.623358                      1.0
# Perm997                1201.5  0.260318                      1.0
# Perm998                1204.0  0.641791                      1.0
# Perm999                1209.5  0.270008                      1.0
# True                    481.0  0.808947                      1.0
#
# [1001 rows x 6 columns]
# Interactome:  HEKGATA4-HEKTBX5
# Case interactome muts: 11
# Case non-interactome muts: 957
# Ctrl interactome muts: 7
# Ctrl non-interactome muts: 469
# Odds ratio: 0.7701149425287356
# Synonymous OR:  0.7701149425287356
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  4.0                 262.0               14.0
# Perm1                  2.0                 269.0               16.0
# Perm2                  2.0                 242.0               16.0
# Perm3                  2.0                 244.0               16.0
# Perm4                  6.0                 240.0               12.0
# ...                    ...                   ...                ...
# Perm996                2.0                 257.0               16.0
# Perm997                4.0                 264.0               14.0
# Perm998                2.0                 338.0               16.0
# Perm999                2.0                 392.0               16.0
# True                  11.0                 957.0                7.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1164.0  1.269357                      1.0
# Perm1                  1157.0  0.537639                      1.0
# Perm2                  1184.0  0.611570                      1.0
# Perm3                  1182.0  0.605533                      1.0
# Perm4                  1186.0  2.470833                      1.0
# ...                       ...       ...                      ...
# Perm996                1169.0  0.568580                      1.0
# Perm997                1162.0  1.257576                      1.0
# Perm998                1088.0  0.402367                      1.0
# Perm999                1034.0  0.329719                      1.0
# True                    469.0  0.770115                      1.0
#
# [1001 rows x 6 columns]
# Case interactome muts: 11
# Case non-interactome muts: 985
# Ctrl interactome muts: 7
# Ctrl non-interactome muts: 477
# Odds ratio: 0.7609862218999275
# Synonymous OR:  0.7609862218999275
# Corrected OR:  1.0
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  6.0                 375.0               12.0
# Perm1                  1.0                 271.0               17.0
# Perm2                  2.0                 265.0               16.0
# Perm3                  5.0                 277.0               13.0
# Perm4                  6.0                 271.0               12.0
# ...                    ...                   ...                ...
# Perm996                6.0                 266.0               12.0
# Perm997                4.0                 276.0               14.0
# Perm998                2.0                 231.0               16.0
# Perm999                2.0                 257.0               16.0
# True                  11.0                 985.0                7.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1087.0  1.449333                      1.0
# Perm1                  1191.0  0.258520                      1.0
# Perm2                  1197.0  0.564623                      1.0
# Perm3                  1185.0  1.645376                      1.0
# Perm4                  1191.0  2.197417                      1.0
# ...                       ...       ...                      ...
# Perm996                1196.0  2.248120                      1.0
# Perm997                1186.0  1.227743                      1.0
# Perm998                1231.0  0.666126                      1.0
# Perm999                1205.0  0.586089                      1.0
# True                    477.0  0.760986                      1.0
#
# [1001 rows x 6 columns]
# Interactome:  HEK-GATA4
# Case interactome muts: 31
# Case non-interactome muts: 2689
# Ctrl interactome muts: 7
# Ctrl non-interactome muts: 1309
# Odds ratio: 2.1558200074377094
# Synonymous OR:  0.735966735966736
# Corrected OR:  2.9292356598235543
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 19.0                1823.0               19.0
# Perm1                 21.0                1903.0               17.0
# Perm2                 23.0                1895.0               15.0
# Perm3                 15.0                1898.0               23.0
# Perm4                 17.0                1905.0               21.0
# ...                    ...                   ...                ...
# Perm996               17.0                1858.0               21.0
# Perm997               19.0                1898.0               19.0
# Perm998               15.0                1814.0               23.0
# Perm999               25.0                1888.0               13.0
# True                  31.0                2689.0                7.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2175.0  1.193088                 2.187576
# Perm1                  2095.0  1.359927                 1.044679
# Perm2                  2103.0  1.701636                 1.784287
# Perm3                  2100.0  0.721583                 0.695883
# Perm4                  2093.0  0.889414                 2.170034
# ...                       ...       ...                      ...
# Perm996                2140.0  0.932390                 1.605971
# Perm997                2100.0  1.106428                 0.568239
# Perm998                2184.0  0.785197                 0.281361
# Perm999                2110.0  2.149201                 0.709578
# True                   1309.0  2.155820                 2.929236
#
# [1001 rows x 6 columns]
# Case interactome muts: 41
# Case non-interactome muts: 2860
# Ctrl interactome muts: 7
# Ctrl non-interactome muts: 1338
# Odds ratio: 2.74015984015984
# Synonymous OR:  0.7272727272727273
# Corrected OR:  3.76771978021978
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 25.0                2058.0               23.0
# Perm1                 28.0                2083.0               20.0
# Perm2                 22.0                2064.0               26.0
# Perm3                 26.0                2009.0               22.0
# Perm4                 30.0                1987.0               18.0
# ...                    ...                   ...                ...
# Perm996               26.0                2074.0               22.0
# Perm997               22.0                2031.0               26.0
# Perm998               23.0                2076.0               25.0
# Perm999               25.0                2019.0               23.0
# True                  41.0                2860.0                7.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2140.0  1.130266                 1.314548
# Perm1                  2115.0  1.421507                 2.307433
# Perm2                  2134.0  0.874851                 0.661111
# Perm3                  2189.0  1.287705                 0.699494
# Perm4                  2211.0  1.854555                 0.637016
# ...                       ...       ...                      ...
# Perm996                2124.0  1.210309                 2.132365
# Perm997                2167.0  0.902814                 0.673358
# Perm998                2122.0  0.940385                 0.409656
# Perm999                2179.0  1.173095                 0.391978
# True                   1338.0  2.740160                 3.767720
#
# [1001 rows x 6 columns]
# Interactome:  HEK-TBX5
# Case interactome muts: 13
# Case non-interactome muts: 2707
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 1315
# Odds ratio: 6.315108976727004
# Synonymous OR:  0.8186223606784354
# Corrected OR:  7.7143128261159895
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  7.0                1889.0                7.0
# Perm1                  8.0                1923.0                6.0
# Perm2                  8.0                1890.0                6.0
# Perm3                  8.0                1910.0                6.0
# Perm4                  9.0                1877.0                5.0
# ...                    ...                   ...                ...
# Perm996                5.0                1973.0                9.0
# Perm997                5.0                1935.0                9.0
# Perm998                7.0                1847.0                7.0
# Perm999                6.0                1879.0                8.0
# True                  13.0                2707.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2133.0  1.129169                 1.678628
# Perm1                  2099.0  1.455365                 1.534483
# Perm2                  2132.0  1.504056                 0.709376
# Perm3                  2112.0  1.474346                 0.658887
# Perm4                  2145.0  2.057006                 1.576279
# ...                       ...       ...                      ...
# Perm996                2049.0  0.576956                 0.202209
# Perm997                2087.0  0.599196                 0.630012
# Perm998                2175.0  1.177585                 1.217617
# Perm999                2143.0  0.855375                 0.530672
# True                   1315.0  6.315109                 7.714313
#
# [1001 rows x 6 columns]
# Case interactome muts: 20
# Case non-interactome muts: 2881
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 1344
# Odds ratio: 9.330093717459215
# Synonymous OR:  0.8089471913891692
# Corrected OR:  11.533625206655405
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  3.0                2027.0               18.0
# Perm1                  7.0                2072.0               14.0
# Perm2                  8.0                2078.0               13.0
# Perm3                 11.0                2047.0               10.0
# Perm4                 12.0                2040.0                9.0
# ...                    ...                   ...                ...
# Perm996                8.0                2078.0               13.0
# Perm997               13.0                2056.0                8.0
# Perm998               11.0                2032.0               10.0
# Perm999                8.0                2102.0               13.0
# True                  20.0                2881.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2198.0  0.180727                 0.067718
# Perm1                  2153.0  0.519546                 0.947205
# Perm2                  2147.0  0.635818                 0.687979
# Perm3                  2178.0  1.170396                 1.269863
# Perm4                  2185.0  1.428105                 2.825794
# ...                       ...       ...                      ...
# Perm996                2147.0  0.635818                 1.175080
# Perm997                2169.0  1.714312                 0.672876
# Perm998                2193.0  1.187156                 0.137847
# Perm999                2123.0  0.621533                 4.837610
# True                   1344.0  9.330094                11.533625
#
# [1001 rows x 6 columns]
# Interactome:  HEKGATA4-HEKTBX5
# Case interactome muts: 40
# Case non-interactome muts: 2680
# Ctrl interactome muts: 8
# Ctrl non-interactome muts: 1308
# Odds ratio: 2.4402985074626864
# Synonymous OR:  0.7701149425287356
# Corrected OR:  3.16874582312319
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 16.0                1854.0               32.0
# Perm1                 17.0                1863.0               31.0
# Perm2                 29.0                1831.0               19.0
# Perm3                 24.0                1908.0               24.0
# Perm4                 22.0                1853.0               26.0
# ...                    ...                   ...                ...
# Perm996               24.0                1835.0               24.0
# Perm997               20.0                1871.0               28.0
# Perm998               22.0                1819.0               26.0
# Perm999               20.0                1854.0               28.0
# True                  40.0                2680.0                8.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2134.0  0.575512                 0.282524
# Perm1                  2125.0  0.625509                 0.314514
# Perm2                  2157.0  1.798068                 0.857818
# Perm3                  2080.0  1.090147                 1.422808
# Perm4                  2135.0  0.974926                 0.495231
# ...                       ...       ...                      ...
# Perm996                2153.0  1.173297                 1.805072
# Perm997                2117.0  0.808200                 0.952443
# Perm998                2169.0  1.008965                 0.518375
# Perm999                2134.0  0.822161                 1.630297
# True                   1308.0  2.440299                 3.168746
#
# [1001 rows x 6 columns]
# Case interactome muts: 54
# Case non-interactome muts: 2847
# Ctrl interactome muts: 8
# Ctrl non-interactome muts: 1337
# Odds ratio: 3.1699157007376186
# Synonymous OR:  0.7609862218999275
# Corrected OR:  4.165536260069731
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 33.0                2069.0               29.0
# Perm1                 29.0                1983.0               33.0
# Perm2                 26.0                2060.0               36.0
# Perm3                 26.0                2036.0               36.0
# Perm4                 34.0                2039.0               28.0
# ...                    ...                   ...                ...
# Perm996               35.0                1966.0               27.0
# Perm997               28.0                1952.0               34.0
# Perm998               33.0                2041.0               29.0
# Perm999               29.0                1999.0               33.0
# True                  54.0                2847.0                8.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2115.0  1.163231                 0.788332
# Perm1                  2201.0  0.975397                 0.587577
# Perm2                  2124.0  0.744660                 0.828596
# Perm3                  2148.0  0.761952                 2.335364
# Perm4                  2145.0  1.277412                 1.767025
# ...                       ...       ...                      ...
# Perm996                2218.0  1.462454                 1.479649
# Perm997                2232.0  0.941659                 0.963326
# Perm998                2143.0  1.194800                 0.509935
# Perm999                2185.0  0.960556                 0.947917
# True                   1337.0  3.169916                 4.165536
#
# [1001 rows x 6 columns]
# Interactome:  HEK-GATA4
# Case interactome muts: 22
# Case non-interactome muts: 2270
# Ctrl interactome muts: 6
# Ctrl non-interactome muts: 1165
# Odds ratio: 1.881791483113069
# Synonymous OR:  0.735966735966736
# Corrected OR:  2.5568974671677576
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  7.0                1508.0               21.0
# Perm1                 11.0                1585.0               17.0
# Perm2                 14.0                1599.0               14.0
# Perm3                 14.0                1533.0               14.0
# Perm4                  9.0                1535.0               19.0
# ...                    ...                   ...                ...
# Perm996               13.0                1490.0               15.0
# Perm997               17.0                1511.0               11.0
# Perm998               11.0                1488.0               17.0
# Perm999               15.0                1515.0               13.0
# True                  22.0                2270.0                6.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1927.0  0.425950                 0.397248
# Perm1                  1850.0  0.755242                 1.200301
# Perm2                  1836.0  1.148218                 1.757241
# Perm3                  1902.0  1.240705                 2.023740
# Perm4                  1900.0  0.586319                 0.587957
# ...                       ...       ...                      ...
# Perm996                1945.0  1.131320                 1.311017
# Perm997                1924.0  1.967872                 1.344251
# Perm998                1947.0  0.846656                 0.417848
# Perm999                1920.0  1.462300                 0.947974
# True                   1165.0  1.881791                 2.556897
#
# [1001 rows x 6 columns]
# Case interactome muts: 27
# Case non-interactome muts: 2384
# Ctrl interactome muts: 6
# Ctrl non-interactome muts: 1189
# Odds ratio: 2.2443372483221475
# Synonymous OR:  0.7272727272727273
# Corrected OR:  3.085963716442953
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 20.0                1572.0               13.0
# Perm1                 14.0                1587.0               19.0
# Perm2                 14.0                1669.0               19.0
# Perm3                 17.0                1646.0               16.0
# Perm4                 13.0                1608.0               20.0
# ...                    ...                   ...                ...
# Perm996               11.0                1646.0               22.0
# Perm997               18.0                1676.0               15.0
# Perm998               17.0                1605.0               16.0
# Perm999               14.0                1603.0               19.0
# True                  27.0                2384.0                6.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  2001.0  1.958309                 1.335414
# Perm1                  1986.0  0.922097                 1.534679
# Perm2                  1904.0  0.840592                 0.571171
# Perm3                  1927.0  1.243887                 3.568909
# Perm4                  1965.0  0.794310                 0.139671
# ...                       ...       ...                      ...
# Perm996                1927.0  0.585358                 0.598241
# Perm997                1897.0  1.358234                 0.566473
# Perm998                1968.0  1.302804                 4.040580
# Perm999                1970.0  0.905539                 0.449010
# True                   1189.0  2.244337                 3.085964
#
# [1001 rows x 6 columns]
# Interactome:  HEK-TBX5
# Case interactome muts: 13
# Case non-interactome muts: 2279
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 1170
# Odds ratio: 6.673979815708644
# Synonymous OR:  0.8186223606784354
# Corrected OR:  8.152696696652123
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  6.0                1500.0                8.0
# Perm1                  3.0                1549.0               11.0
# Perm2                  5.0                1583.0                9.0
# Perm3                  7.0                1489.0                7.0
# Perm4                  8.0                1573.0                6.0
# ...                    ...                   ...                ...
# Perm996                5.0                1519.0                9.0
# Perm997                6.0                1537.0                8.0
# Perm998                4.0                1532.0               10.0
# Perm999                2.0                1501.0               12.0
# True                  13.0                2279.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1949.0  0.974500                 4.662291
# Perm1                  1900.0  0.334527                 0.527325
# Perm2                  1866.0  0.654875                 0.273238
# Perm3                  1960.0  1.316320                 0.570090
# Perm4                  1876.0  1.590167                 4.327029
# ...                       ...       ...                      ...
# Perm996                1930.0  0.705874                 0.878764
# Perm997                1912.0  0.932986                 2.061144
# Perm998                1917.0  0.500522                 0.612555
# Perm999                1948.0  0.216300                 0.097493
# True                   1170.0  6.673980                 8.152697
#
# [1001 rows x 6 columns]
# Case interactome muts: 16
# Case non-interactome muts: 2395
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 1194
# Odds ratio: 7.976617954070981
# Synonymous OR:  0.8089471913891692
# Corrected OR:  9.860492797277766
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  9.0                1698.0                8.0
# Perm1                  8.0                1622.0                9.0
# Perm2                  6.0                1610.0               11.0
# Perm3                 10.0                1642.0                7.0
# Perm4                  8.0                1635.0                9.0
# ...                    ...                   ...                ...
# Perm996                5.0                1620.0               12.0
# Perm997                6.0                1643.0               11.0
# Perm998               10.0                1614.0                7.0
# Perm999                9.0                1668.0                8.0
# True                  16.0                2395.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1891.0  1.252871                 2.032137
# Perm1                  1967.0  1.077956                 0.700913
# Perm2                  1979.0  0.670469                 0.167684
# Perm3                  1947.0  1.693927                 0.909096
# Perm4                  1954.0  1.062317                 0.109515
# ...                       ...       ...                      ...
# Perm996                1969.0  0.506430                 0.371621
# Perm997                1946.0  0.646047                 0.592209
# Perm998                1975.0  1.748097                 1.237052
# Perm999                1921.0  1.295638                 2.012037
# True                   1194.0  7.976618                 9.860493
#
# [1001 rows x 6 columns]
# Interactome:  HEKGATA4-HEKTBX5
# Case interactome muts: 31
# Case non-interactome muts: 2261
# Ctrl interactome muts: 7
# Ctrl non-interactome muts: 1164
# Odds ratio: 2.279901434257914
# Synonymous OR:  0.7701149425287356
# Corrected OR:  2.9604690265737093
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 15.0                1542.0               23.0
# Perm1                 19.0                1537.0               19.0
# Perm2                 13.0                1472.0               25.0
# Perm3                 16.0                1527.0               22.0
# Perm4                 12.0                1549.0               26.0
# ...                    ...                   ...                ...
# Perm996               15.0                1551.0               23.0
# Perm997               17.0                1537.0               21.0
# Perm998               16.0                1539.0               22.0
# Perm999               17.0                1506.0               21.0
# True                  31.0                2261.0                7.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1883.0  0.796397                 0.610862
# Perm1                  1888.0  1.228367                 1.430631
# Perm2                  1953.0  0.689918                 0.610392
# Perm3                  1898.0  0.903971                 0.430031
# Perm4                  1876.0  0.558971                 0.459851
# ...                       ...       ...                      ...
# Perm996                1874.0  0.787991                 0.574621
# Perm997                1888.0  0.994392                 2.491964
# Perm998                1886.0  0.891252                 1.273046
# Perm999                1919.0  1.031525                 0.595992
# True                   1164.0  2.279901                 2.960469
#
# [1001 rows x 6 columns]
# Case interactome muts: 38
# Case non-interactome muts: 2373
# Ctrl interactome muts: 7
# Ctrl non-interactome muts: 1188
# Odds ratio: 2.7177171753657214
# Synonymous OR:  0.7609862218999275
# Corrected OR:  3.5713093051546885
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                 19.0                1619.0               26.0
# Perm1                 26.0                1636.0               19.0
# Perm2                 21.0                1681.0               24.0
# Perm3                 15.0                1628.0               30.0
# Perm4                 24.0                1613.0               21.0
# ...                    ...                   ...                ...
# Perm996               21.0                1592.0               24.0
# Perm997               22.0                1614.0               23.0
# Perm998               19.0                1550.0               26.0
# Perm999               22.0                1611.0               23.0
# True                  38.0                2373.0                7.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                  1942.0  0.876562                 0.538319
# Perm1                  1925.0  1.610153                 1.942809
# Perm2                  1880.0  0.978584                 1.183718
# Perm3                  1933.0  0.593673                 0.442314
# Perm4                  1948.0  1.380214                 1.410758
# ...                       ...       ...                      ...
# Perm996                1969.0  1.082208                 0.628626
# Perm997                1947.0  1.153871                 1.610863
# Perm998                2011.0  0.948114                 1.419903
# Perm999                1950.0  1.157801                 1.676627
# True                   1188.0  2.717717                 3.571309
#
# [1001 rows x 6 columns]
# Interactome:  HEK-GATA4
# Case interactome muts: 9
# Case non-interactome muts: 383
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 122
# Odds ratio: 2.866840731070496
# Synonymous OR:  0.735966735966736
# Corrected OR:  3.895340089392397
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  3.0                 141.0                7.0
# Perm1                  3.0                 133.0                7.0
# Perm2                  2.0                 108.0                8.0
# Perm3                  2.0                 130.0                8.0
# Perm4                  2.0                 126.0                8.0
# ...                    ...                   ...                ...
# Perm996                5.0                 146.0                5.0
# Perm997                3.0                 123.0                7.0
# Perm998                2.0                 131.0                8.0
# Perm999                2.0                 124.0                8.0
# True                   9.0                 383.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   364.0  1.106383                 0.355878
# Perm1                   372.0  1.198711                 3.417813
# Perm2                   397.0  0.918981                 1.164550
# Perm3                   375.0  0.721154                 2.761317
# Perm4                   379.0  0.751984                 0.864039
# ...                       ...       ...                      ...
# Perm996                 359.0  2.458904                 6.255030
# Perm997                 382.0  1.331010                 3.897081
# Perm998                 374.0  0.713740                 1.331148
# Perm999                 381.0  0.768145                 0.356714
# True                    122.0  2.866841                 3.895340
#
# [1001 rows x 6 columns]
# Case interactome muts: 13
# Case non-interactome muts: 433
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 126
# Odds ratio: 3.7829099307159355
# Synonymous OR:  0.7272727272727273
# Corrected OR:  5.201501154734411
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  3.0                 156.0               11.0
# Perm1                  3.0                 147.0               11.0
# Perm2                  3.0                 149.0               11.0
# Perm3                  4.0                 146.0               10.0
# Perm4                  5.0                 122.0                9.0
# ...                    ...                   ...                ...
# Perm996                5.0                 139.0                9.0
# Perm997                3.0                 145.0               11.0
# Perm998                4.0                 137.0               10.0
# Perm999                0.5                 138.5               14.5
# True                  13.0                 433.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   403.0  0.704545                 0.212570
# Perm1                   412.0  0.764378                 0.814883
# Perm2                   410.0  0.750458                 0.524123
# Perm3                   413.0  1.131507                 1.348583
# Perm4                   437.0  1.989982                13.967777
# ...                       ...       ...                      ...
# Perm996                 420.0  1.678657                 5.323212
# Perm997                 414.0  0.778683                 0.108234
# Perm998                 422.0  1.232117                 0.373567
# Perm999                 421.5  0.104942                 0.153175
# True                    126.0  3.782910                 5.201501
#
# [1001 rows x 6 columns]
# Interactome:  HEK-TBX5
# Case interactome muts: 0.5
# Case non-interactome muts: 392.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 123.5
# Odds ratio: 0.3146496815286624
# Synonymous OR:  0.8186223606784354
# Corrected OR:  0.3843648752373386
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                 128.5                0.5
# Perm1                  0.5                 146.5                0.5
# Perm2                  0.5                 130.5                0.5
# Perm3                  0.5                 131.5                0.5
# Perm4                  0.5                 129.5                0.5
# ...                    ...                   ...                ...
# Perm996                0.5                 133.5                0.5
# Perm997                0.5                 139.5                0.5
# Perm998                0.5                 134.5                0.5
# Perm999                0.5                 134.5                0.5
# True                   0.5                 392.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   387.5  3.015564                23.034166
# Perm1                   369.5  2.522184                 0.819012
# Perm2                   385.5  2.954023                 1.622889
# Perm3                   384.5  2.923954                 2.689825
# Perm4                   386.5  2.984556                 6.356752
# ...                       ...       ...                      ...
# Perm996                 382.5  2.865169                 2.257851
# Perm997                 376.5  2.698925                 2.359132
# Perm998                 381.5  2.836431                 3.934032
# Perm999                 381.5  2.836431                 2.721723
# True                    123.5  0.314650                 0.384365
#
# [1001 rows x 6 columns]
# Case interactome muts: 3.5
# Case non-interactome muts: 443.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 127.5
# Odds ratio: 2.012401352874859
# Synonymous OR:  0.8089471913891692
# Corrected OR:  2.4876795102274247
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                 166.5                3.5
# Perm1                  2.0                 182.0                1.0
# Perm2                  1.0                 156.0                2.0
# Perm3                  2.0                 147.0                1.0
# Perm4                  1.0                 170.0                2.0
# ...                    ...                   ...                ...
# Perm996                1.0                 162.0                2.0
# Perm997                0.5                 151.5                3.5
# Perm998                1.0                 155.0                2.0
# Perm999                0.5                 166.5                3.5
# True                   3.5                 443.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   404.5  0.347061                 0.511625
# Perm1                   388.0  4.263736                 2.266861
# Perm2                   414.0  1.326923                 7.828664
# Perm3                   423.0  5.755102                 4.485116
# Perm4                   400.0  1.176471                 0.706752
# ...                       ...       ...                      ...
# Perm996                 408.0  1.259259                 2.667847
# Perm997                 419.5  0.395568                 0.893138
# Perm998                 415.0  1.338710                 1.262212
# Perm999                 404.5  0.347061                 0.108263
# True                    127.5  2.012401                 2.487680
#
# [1001 rows x 6 columns]
# Interactome:  HEKGATA4-HEKTBX5
# Case interactome muts: 9
# Case non-interactome muts: 383
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 122
# Odds ratio: 2.866840731070496
# Synonymous OR:  0.7701149425287356
# Corrected OR:  3.7226140836288533
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  1.0                 137.0                9.0
# Perm1                  2.0                 133.0                8.0
# Perm2                  2.0                 139.0                8.0
# Perm3                  3.0                 130.0                7.0
# Perm4                  1.0                 141.0                9.0
# ...                    ...                   ...                ...
# Perm996                4.0                 132.0                6.0
# Perm997                6.0                 123.0                4.0
# Perm998                3.0                 137.0                7.0
# Perm999                1.0                 145.0                9.0
# True                   9.0                 383.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   368.0  0.298459                 0.250506
# Perm1                   372.0  0.699248                 1.146810
# Perm2                   366.0  0.658273                 0.385535
# Perm3                   375.0  1.236264                 1.969192
# Perm4                   364.0  0.286840                 0.304669
# ...                       ...       ...                      ...
# Perm996                 373.0  1.883838                 1.954054
# Perm997                 382.0  4.658537                25.468681
# Perm998                 368.0  1.151199                 0.812592
# Perm999                 360.0  0.275862                 0.233303
# True                    122.0  2.866841                 3.722614
#
# [1001 rows x 6 columns]
# Case interactome muts: 15
# Case non-interactome muts: 431
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 126
# Odds ratio: 4.385150812064965
# Synonymous OR:  0.7609862218999275
# Corrected OR:  5.762457566073553
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  4.0                 135.0               12.0
# Perm1                  1.0                 147.0               15.0
# Perm2                  3.0                 142.0               13.0
# Perm3                  1.0                 137.0               15.0
# Perm4                  3.0                 166.0               13.0
# ...                    ...                   ...                ...
# Perm996                2.0                 138.0               14.0
# Perm997                7.0                 159.0                9.0
# Perm998                5.0                 131.0               11.0
# Perm999                4.0                 143.0               12.0
# True                  15.0                 431.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   422.0  1.041975                 1.240151
# Perm1                   410.0  0.185941                 0.320084
# Perm2                   415.0  0.674431                 0.596294
# Perm3                   420.0  0.204380                 0.234545
# Perm4                   391.0  0.543559                 0.274939
# ...                       ...       ...                      ...
# Perm996                 419.0  0.433747                 1.154551
# Perm997                 398.0  1.946890                 1.391189
# Perm998                 426.0  1.478140                 0.792733
# Perm999                 414.0  0.965035                 1.087191
# True                    126.0  4.385151                 5.762458
#
# [1001 rows x 6 columns]
# Interactome:  HEK-GATA4
# Case interactome muts: 0.5
# Case non-interactome muts: 36.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 20.5
# Odds ratio: 0.5616438356164384
# Synonymous OR:  0.735966735966736
# Corrected OR:  0.763137528055104
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                  11.5                0.5
# Perm1                  0.5                  13.5                0.5
# Perm2                  0.5                  13.5                0.5
# Perm3                  0.5                  14.5                0.5
# Perm4                  0.5                  14.5                0.5
# ...                    ...                   ...                ...
# Perm996                0.5                  11.5                0.5
# Perm997                0.5                   8.5                0.5
# Perm998                0.5                   8.5                0.5
# Perm999                0.5                  12.5                0.5
# True                   0.5                  36.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                    45.5  3.956522                12.382723
# Perm1                    43.5  3.222222                 2.962455
# Perm2                    43.5  3.222222                 2.398677
# Perm3                    42.5  2.931034                 1.543177
# Perm4                    42.5  2.931034                15.287531
# ...                       ...       ...                      ...
# Perm996                  45.5  3.956522                 2.124382
# Perm997                  48.5  5.705882                18.184469
# Perm998                  48.5  5.705882                 1.868834
# Perm999                  44.5  3.560000                17.365891
# True                     20.5  0.561644                 0.763138
#
# [1001 rows x 6 columns]
# Case interactome muts: 1.5
# Case non-interactome muts: 43.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 21.5
# Odds ratio: 1.4827586206896552
# Synonymous OR:  0.7272727272727273
# Corrected OR:  2.038793103448276
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                   5.5                1.5
# ...
#
# [1001 rows x 6 columns]
# Case interactome muts: 16
# Case non-interactome muts: 482
# Ctrl interactome muts: 1
# Ctrl non-interactome muts: 126
# Odds ratio: 4.182572614107884
# Synonymous OR:  0.7447306791569087
# Corrected OR:  5.616221717685743
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  4.0                 192.0               13.0
# Perm1                  7.0                 179.0               10.0
# Perm2                  6.0                 180.0               11.0
# Perm3                  7.0                 173.0               10.0
# Perm4                  4.0                 177.0               13.0
# ...                    ...                   ...                ...
# Perm996                6.0                 176.0               11.0
# Perm997                6.0                 180.0               11.0
# Perm998                5.0                 177.0               12.0
# Perm999                6.0                 191.0               11.0
# True                  16.0                 482.0                1.0
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                   416.0  0.666667                 0.577984
# Perm1                   429.0  1.677654                 2.960565
# Perm2                   428.0  1.296970                 1.282262
# Perm3                   435.0  1.760116                 0.885782
# Perm4                   431.0  0.749239                 0.515364
# ...                       ...       ...                      ...
# Perm996                 432.0  1.338843                 1.480910
# Perm997                 428.0  1.296970                 2.743342
# Perm998                 431.0  1.014595                 0.841487
# Perm999                 417.0  1.190861                 0.630780
# True                    126.0  4.182573                 5.616222
#
# [1001 rows x 6 columns]
# Interactome:  HEK-GATA4
# Case interactome muts: 1.5
# Case non-interactome muts: 66.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 20.5
# Odds ratio: 0.924812030075188
# Synonymous OR:  0.6610644257703081
# Corrected OR:  1.3989741302408565
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                  14.5                1.5
# Perm1                  0.5                  20.5                1.5
# Perm2                  0.5                  15.5                1.5
# Perm3                  0.5                  27.5                1.5
# Perm4                  0.5                  20.5                1.5
# ...                    ...                   ...                ...
# Perm996                0.5                  19.5                1.5
# Perm997                1.5                  20.5                0.5
# Perm998                0.5                  25.5                1.5
# Perm999                1.5                  18.5                0.5
# True                   1.5                  66.5                0.5
#
#          ctrl_nonintact_count         OR  synonymous-corrected OR
# Perm0                    72.5   1.666667                 8.988604
# Perm1                    66.5   1.081301                 2.476443
# Perm2                    71.5   1.537634                 3.564003
# Perm3                    59.5   0.721212                 3.812455
# Perm4                    66.5   1.081301                 0.691699
# ...                       ...        ...                      ...
# Perm996                  67.5   1.153846                 1.260472
# Perm997                  66.5   9.731707                25.981205
# Perm998                  61.5   0.803922                 0.864745
# Perm999                  68.5  11.108108                 7.133058
# True                     20.5   0.924812                 1.398974
#
# [1001 rows x 6 columns]
# Case interactome muts: 2.5
# Case non-interactome muts: 76.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 21.5
# Odds ratio: 1.4052287581699345
# Synonymous OR:  0.6521739130434783
# Corrected OR:  2.154684095860566
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                  25.5                2.5
# Perm1                  0.5                  21.5                2.5
# Perm2                  1.0                  17.0                1.0
# Perm3                  1.0                  23.0                1.0
# Perm4                  0.5                  19.5                2.5
# ...                    ...                   ...                ...
# Perm996                0.5                  22.5                2.5
# Perm997                1.0                  24.0                1.0
# Perm998                0.5                  14.5                2.5
# Perm999                2.5                  26.5                0.5
# True                   2.5                  76.5                0.5
#
#          ctrl_nonintact_count         OR  synonymous-corrected OR
# Perm0                    72.5   0.568627                 0.538018
# Perm1                    76.5   0.711628                 0.427543
# Perm2                    80.0   4.705882                 0.857449
# Perm3                    74.0   3.217391                 0.876061
# Perm4                    78.5   0.805128                 1.362859
# ...                       ...        ...                      ...
# Perm996                  75.5   0.671111                 0.440892
# Perm997                  73.0   3.041667                 2.967236
# Perm998                  83.5   1.151724                 2.603661
# Perm999                  71.5  13.490566                34.437020
# True                     21.5   1.405229                 2.154684
#
# [1001 rows x 6 columns]
# Interactome:  HEK-TBX5
# Case interactome muts: 0.5
# Case non-interactome muts: 67.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 20.5
# Odds ratio: 0.3037037037037037
# Synonymous OR:  0.8832866479925303
# Corrected OR:  0.3438336856941508
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                  24.5                0.5
# Perm1                  0.5                  25.5                0.5
# Perm2                  0.5                  18.5                0.5
# Perm3                  0.5                  18.5                0.5
# Perm4                  0.5                  26.5                0.5
# ...                    ...                   ...                ...
# Perm996                0.5                  16.5                0.5
# Perm997                0.5                  24.5                0.5
# Perm998                0.5                  17.5                0.5
# Perm999                0.5                  21.5                0.5
# True                   0.5                  67.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                    63.5  2.591837                 2.223963
# Perm1                    62.5  2.450980                11.059350
# Perm2                    69.5  3.756757                 4.690994
# Perm3                    69.5  3.756757                12.635421
# Perm4                    61.5  2.320755                 1.242309
# ...                       ...       ...                      ...
# Perm996                  71.5  4.333333                 4.218543
# Perm997                  63.5  2.591837                 5.442221
# Perm998                  70.5  4.028571                 8.492308
# Perm999                  66.5  3.093023                 9.551167
# True                     20.5  0.303704                 0.343834
#
# [1001 rows x 6 columns]
# Case interactome muts: 2.5
# Case non-interactome muts: 76.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 21.5
# Odds ratio: 1.4052287581699345
# Synonymous OR:  0.8713768115942029
# Corrected OR:  1.6126533773592595
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  1.0                  23.0                1.0
# Perm1                  0.5                  21.5                2.5
# Perm2                  2.5                  14.5                0.5
# Perm3                  1.0                  21.0                1.0
# Perm4                  1.0                  25.0                1.0
# ...                    ...                   ...                ...
# Perm996                0.5                  24.5                2.5
# Perm997                1.0                  15.0                1.0
# Perm998                1.0                  28.0                1.0
# Perm999                0.5                  20.5                2.5
# True                   2.5                  76.5                0.5
#
#          ctrl_nonintact_count         OR  synonymous-corrected OR
# Perm0                    74.0   3.217391                 0.985689
# Perm1                    76.5   0.711628                 0.244747
# Perm2                    83.5  28.793103                40.203610
# Perm3                    76.0   3.619048                20.738613
# Perm4                    72.0   2.880000                23.642005
# ...                       ...        ...                      ...
# Perm996                  73.5   0.600000                 0.595142
# Perm997                  82.0   5.466667                 1.748943
# Perm998                  69.0   2.464286                 5.669258
# Perm999                  77.5   0.756098                 0.593982
# True                     21.5   1.405229                 1.612653
#
# [1001 rows x 6 columns]
# Interactome:  HEKGATA4-HEKTBX5
# Case interactome muts: 1.5
# Case non-interactome muts: 66.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 20.5
# Odds ratio: 0.924812030075188
# Synonymous OR:  0.7549295774647887
# Corrected OR:  1.2250308607339244
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                  21.5                1.5
# Perm1                  0.5                  25.5                1.5
# Perm2                  0.5                  20.5                1.5
# Perm3                  1.5                  20.5                0.5
# Perm4                  0.5                  17.5                1.5
# ...                    ...                   ...                ...
# Perm996                0.5                  25.5                1.5
# Perm997                0.5                  16.5                1.5
# Perm998                1.5                  17.5                0.5
# Perm999                0.5                  23.5                1.5
# True                   1.5                  66.5                0.5
#
#          ctrl_nonintact_count         OR  synonymous-corrected OR
# Perm0                    65.5   1.015504                 0.539349
# Perm1                    61.5   0.803922                 0.605102
# Perm2                    66.5   1.081301                 1.367322
# Perm3                    66.5   9.731707                 3.555044
# Perm4                    69.5   1.323810                 1.445827
# ...                       ...        ...                      ...
# Perm996                  61.5   0.803922                 1.751706
# Perm997                  70.5   1.424242                 1.941717
# Perm998                  69.5  11.914286                13.012446
# Perm999                  63.5   0.900709                 0.380060
# True                     20.5   0.924812                 1.225031
#
# [1001 rows x 6 columns]
# Case interactome muts: 3.5
# Case non-interactome muts: 75.5
# Ctrl interactome muts: 0.5
# Ctrl non-interactome muts: 21.5
# Odds ratio: 1.9933774834437086
# Synonymous OR:  0.7447306791569087
# Corrected OR:  2.676642092548627
#          case_intact_count  case_nonintact_count  ctrl_intact_count  \
# Perm0                  0.5                  21.5                3.5
# Perm1                  1.0                  29.0                2.0
# Perm2                  2.0                  25.0                1.0
# Perm3                  0.5                  28.5                3.5
# Perm4                  0.5                  27.5                3.5
# ...                    ...                   ...                ...
# Perm996                1.0                  20.0                2.0
# Perm997                0.5                  18.5                3.5
# Perm998                0.5                  26.5                3.5
# Perm999                1.0                  22.0                2.0
# True                   3.5                  75.5                0.5
#
#          ctrl_nonintact_count        OR  synonymous-corrected OR
# Perm0                    75.5  0.501661                 0.508235
# Perm1                    67.0  1.155172                 1.898914
# Perm2                    71.0  5.680000                11.159317
# Perm3                    68.5  0.343358                 0.217263
# Perm4                    69.5  0.361039                 2.607575
# ...                       ...       ...                      ...
# Perm996                  76.0  1.900000                 2.768849
# Perm997                  78.5  0.606178                 0.223473
# Perm998                  70.5  0.380054                 0.934505
# Perm999                  74.0  1.681818                 1.768986
# True                     21.5  1.993377                 2.676642
#
# [1001 rows x 6 columns]
#          Interactome Cell Type   Variant Type Included Genes     Correction  \
# 0          HEK-GATA4       HEK  lof-inherited   unknownGenes       original
# 1          HEK-GATA4       HEK  lof-inherited   unknownGenes  syn-corrected
# 2          HEK-GATA4       HEK  lof-inherited       allGenes       original
# 3          HEK-GATA4       HEK  lof-inherited       allGenes  syn-corrected
# 4           HEK-TBX5       HEK  lof-inherited   unknownGenes       original
# ..               ...       ...            ...            ...            ...
# 67          HEK-TBX5       HEK     splice-dnv       allGenes  syn-corrected
# 68  HEKGATA4-HEKTBX5       HEK     splice-dnv   unknownGenes       original
# 69  HEKGATA4-HEKTBX5       HEK     splice-dnv   unknownGenes  syn-corrected
# 70  HEKGATA4-HEKTBX5       HEK     splice-dnv       allGenes       original
# 71  HEKGATA4-HEKTBX5       HEK     splice-dnv       allGenes  syn-corrected
#
#     case_intact_count  case_nonintact_count  ctrl_intact_count  \
# 0                25.0                9670.0               25.0
# 1                25.0                9670.0               25.0
# 2                27.0                9856.0               28.0
# 3                27.0                9856.0               28.0
# 4                18.0                9677.0               21.0
# ..                ...                   ...                ...
# 67                2.5                  76.5                0.5
# 68                1.5                  66.5                0.5
# 69                1.5                  66.5                0.5
# 70                3.5                  75.5                0.5
# 71                3.5                  75.5                0.5
#
#     ctrl_nonintact_count        OR  synonymous-corrected OR
# 0                10337.0  1.068976                 1.068976
# 1                10337.0  1.068976                 1.068976
# 2                10493.0  1.026608                 1.026608
# 3                10493.0  1.026608                 1.026608
# 4                10341.0  0.915957                 0.915957
# ..                   ...       ...                      ...
# 67                  21.5  1.405229                 1.612653
# 68                  20.5  0.924812                 1.225031
# 69                  20.5  0.924812                 1.225031
# 70                  21.5  1.993377                 2.676642
# 71                  21.5  1.993377                 2.676642
#
# [72 rows x 11 columns]

# %% [markdown]
# ## Visualize results

# %%
line_list = []
for key in results_dict:
    interactome_name, cell_type, mut_type, known_str, correction = key.split('_')
    OR = results_dict[key]['OR']
    pval = results_dict[key]['PVAL']
    line_list.append([interactome_name, cell_type, mut_type, known_str, correction, OR, pval])
    
data_df = pd.DataFrame(line_list, columns = ['Interactome','Cell Type','Variant Type', 
                                             'Included Genes', 'Correction', 
                                             'Odds Ratio', 'P-value'])
data_df
